# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
## Experimet Set #2: Plot where SIMD and PE are increased for arbitrary
rtl_lut1 = [181, 502,1892,7438]
hls_lut1 = [943,909,2055,7449]
rtl_ff1 = [139, 335,1582, 5510]
hls_ff1 = [1380,1693,2660,7372]
t = np.arange(1,5)
fig, (ax1, ax2) = plt.subplots(ncols=2,sharex=True,sharey=True)
ax1.plot(t, rtl_lut1,'g*-',t,hls_lut1,'bd-')
ax1.set_box_aspect(1)
ax1.legend(['RTL','HLS'])
ax1.grid()
ax1.set(ylabel='LUTs', xlabel='Configs.')
ax1.set_title("(a)")
plt.draw()
ax2.plot(t, rtl_ff1,'g*-',t,hls_ff1,'bd-')
ax2.set_box_aspect(1)
ax2.legend(['RTL','HLS'])
ax2.grid()
ax2.set(ylabel='LUTs', xlabel='Configs.')
ax2.set_title("(b)")
plt.draw()
fig.savefig('paper_figs/expset2.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
## Experiment Set #3: Same as #2, XNOR network
rtl_lut1 = [83,127,316,761]
hls_lut1 = [348,279,646,1361]
rtl_ff1 = [105,177,390,1082]
hls_ff1 = [432,500,702,1434]
t = np.arange(1,5)
fig, (ax1, ax2) = plt.subplots(ncols=2,sharex=True,sharey=True)
ax1.plot(t, rtl_lut1,'g*-',t,hls_lut1,'bd-')
ax1.set_box_aspect(1)
ax1.legend(['RTL','HLS'])
ax1.grid()
ax1.set(ylabel='LUTs', xlabel='Configs.')
ax1.set_title("(a)")
plt.draw()
ax2.plot(t, rtl_ff1,'g*-',t,hls_ff1,'bd-')
ax2.set_box_aspect(1)
ax2.legend(['RTL','HLS'])
ax2.grid()
ax2.set(ylabel='LUTs', xlabel='Configs.')
ax2.set_title("(b)")
plt.draw()
fig.savefig('paper_figs/expset3.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Experiment Set: Fully unfolded, binary weights
plt.rcParams['figure.facecolor'] = 'white'

rtl_lut = [839,2438,10698,43876]
hls_lut = [929,2865,9699,36807]
rtl_ff = [799,2495,3126,9026]
hls_ff = [1116,2466,6201,18713]
t = np.arange(1,5)
fig, (ax1, ax2) = plt.subplots(ncols=2,sharex=True,sharey=True)
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.set_facecolor([235/255,235/255,243/255,255/255])

ax1.plot(t, rtl_lut,'g*-',t,hls_lut,'bd-')
ax1.set_box_aspect(1)
ax1.legend(['RTL','HLS'])
ax1.grid()
ax1.set(ylabel='LUTs', xlabel='Configs.')
ax1.set_title("(a)")
plt.draw()
ax2.plot(t, rtl_ff,'g*-',t,hls_ff,'bd-')
ax2.set_box_aspect(1)
ax2.legend(['RTL','HLS'])
ax2.grid()
ax2.set(ylabel='LUTs', xlabel='Configs.')
ax2.set_title("(b)")
plt.draw()
fig.savefig('paper_figs/expset7a.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Experiment Set: Fully unfolded, XNOR
rtl_lut = [265,761,2569,11762]
hls_lut = [537,1355,3562,11329]
rtl_ff = [378,1082,2954,8163]
hls_ff = [565,1437,3800,9637]
t = np.arange(1,5)
fig, (ax1, ax2) = plt.subplots(ncols=2,sharex=True,sharey=True)
ax1.plot(t, rtl_lut,'g*-',t,hls_lut,'bd-')
ax1.set_box_aspect(1)
ax1.legend(['RTL','HLS'])
ax1.grid()
ax1.set(ylabel='LUTs', xlabel='Configs.')
ax1.set_title("(a)")
plt.draw()
ax2.plot(t, rtl_ff,'g*-',t,hls_ff,'bd-')
ax2.set_box_aspect(1)
ax2.legend(['RTL','HLS'])
ax2.grid()
ax2.set(ylabel='LUTs', xlabel='Configs.')
ax2.set_title("(b)")
plt.draw()
fig.savefig('paper_figs/expset7b.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Experiment Set: Fully unfolded, Arb. prec.
rtl_lut = [1851,7439,29198,113166]
hls_lut = [2023,7445,28032,108772]
rtl_ff = [1400,5546,6257,22302]
hls_ff = [2575,7390,16002,55300]
t = np.arange(1,5)
fig, (ax1, ax2) = plt.subplots(ncols=2,sharex=True,sharey=True)
ax1.plot(t, rtl_lut,'g*-',t,hls_lut,'bd-')
ax1.set_box_aspect(1)
ax1.legend(['RTL','HLS'])
ax1.grid()
ax1.set(ylabel='LUTs', xlabel='Configs.')
ax1.set_title("(a)")
plt.draw()
ax2.plot(t, rtl_ff,'g*-',t,hls_ff,'bd-')
ax2.set_box_aspect(1)
ax2.legend(['RTL','HLS'])
ax2.grid()
ax2.set(ylabel='LUTs', xlabel='Configs.')
ax2.set_title("(b)")
plt.draw()
fig.savefig('paper_figs/expset7c.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=16
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize

IFM_Ch = [2,4,8,16,32,64]
hls_exec = [1006.335,996.55,1000.321,1010.08,1041.241,1160.667]
rtl_exec = [94.297,94.334,94.648,94.902,95.458,96.565]

x = np.arange(len(IFM_Ch))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, hls_exec, width, label='HLS')
rects2 = ax.bar(x + width/2, rtl_exec, width, label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Execution time (sec.)')
ax.set_xlabel('IFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(IFM_Ch)
ax.set_title('(a)')
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/exec_time1.svg', format='svg')
fig.savefig('paper_figs/exec_time1.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=16
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
OFM_Ch = [2,4,8,16,32,64]
hls_exec = [1063.145,1063.364,1068.102,1075.394,1093.422,1157.92]
rtl_exec = [94.077,94.48,94.412,94.312,96.131,97.207]

x = np.arange(len(OFM_Ch))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, hls_exec, width, label='HLS')
rects2 = ax.bar(x + width/2, rtl_exec, width, label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Execution time (sec.)')
ax.set_xlabel('OFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(OFM_Ch)
ax.set_title('(b)')
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
# plt.grid()
plt.draw()
fig.savefig('paper_figs/exec_time2.svg', format='svg')
fig.savefig('paper_figs/exec_time2.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=16
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
PE = [1,2,4,8,16,32,64]
hls_exec = [1026.536,1045.3,1088.477,1095.105,1200.601,1492.561,2632.23]
rtl_exec = [98.129,104.442,103.047,105.019,124.66,150.042,202.88]

x = np.arange(len(PE))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, hls_exec, width, label='HLS')
rects2 = ax.bar(x + width/2, rtl_exec, width, label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Execution time (sec.)')
ax.set_xlabel('Processing elements (PEs)')
ax.set_xticks(x)
ax.set_xticklabels(PE)
ax.set_title('(c)')
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/exec_time3.svg', format='svg')
fig.savefig('paper_figs/exec_time3.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=16
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
SIMD = [1,2,4,8,16,32,64]
hls_exec = [1762.452,1224.871,1109.87,1141.112,1224.022,1530.787,2615.679]
rtl_exec = [131.955,129.995,109.842,137.167,169.923,261.734,226.711]

x = np.arange(len(SIMD))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, hls_exec, width, label='HLS')
rects2 = ax.bar(x + width/2, rtl_exec, width, label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Execution time (sec.)')
ax.set_xlabel('SIMD')
ax.set_xticks(x)
ax.set_xticklabels(SIMD)
ax.set_title('(d)')
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/exec_time4.svg', format='svg')
fig.savefig('paper_figs/exec_time4.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_lut = [2773,2467,2231,3792,6139,8572,11486];
hls_ff = [3273,3275,3277,3511,5301,7440,9652];

rtl_lut = [1140,1170,1423,1717,3411,5075,11676];
rtl_ff = [2224,2286,2352,2428,3485,4727,8084];

SIMD = [1,2,4,8,16,32,64]
x = np.arange(len(SIMD))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_lut,width=width,label='HLS LUT')
rect_rtl_lut = ax.bar(x-width/2,hls_ff,bottom=hls_lut,width=width,label='HLS FF')
rect_hls_ff = ax.bar(x+width/2,rtl_lut,width=width,label='RTL LUT')
rect_rtl_ff = ax.bar(x+width/2,rtl_ff,bottom=rtl_lut,width=width,label='RTL FF')
# rects2 = ax.bar(x + width/2, rtl_exec, width, label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Resource count')
ax.set_xlabel('SIMD')
ax.set_xticks(x)
ax.set_xticklabels(SIMD)
ax.set_title('(d)')
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util1.svg', format='svg')
fig.savefig('paper_figs/res_util1.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
rtl_bram = [32,32,32,32,0,0,0];
hls_bram = [64,64,64,33,0,0,0];
SIMD = [1,2,4,8,16,32,64]
x = np.arange(len(SIMD))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_bram,width=width,label='HLS BRAM')
rect_rtl_lut = ax.bar(x+width/2,rtl_bram,width=width,label='RTL BRAM')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('BRAMs')
ax.set_xlabel('SIMD')
ax.set_xticks(x)
ax.set_xticklabels(SIMD)
ax.set_title('(d)')
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_bram1.svg', format='svg')
fig.savefig('paper_figs/res_bram1.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_lut = [591,707,977,1490,2619,4845,11327];
hls_ff = [1391,1455,1587,1856,2390,3622,9655];

rtl_lut = [282,428,718,1301,3280,5922,11759];
rtl_ff = [201,300,500,902,2942,4223,8541];

PE = [1,2,4,8,16,32,64]
x = np.arange(len(PE))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_lut,width=width,label='HLS LUT')
rect_rtl_lut = ax.bar(x-width/2,hls_ff,bottom=hls_lut,width=width,label='HLS FF')
rect_hls_ff = ax.bar(x+width/2,rtl_lut,width=width,label='RTL LUT')
rect_rtl_ff = ax.bar(x+width/2,rtl_ff,bottom=rtl_lut,width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Resource count')
ax.set_xlabel('Processing elements (PEs)')
ax.set_xticks(x)
ax.set_xticklabels(PE)
ax.set_title("(c)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util2.svg', format='svg')
fig.savefig('paper_figs/res_util2.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_bram = [4,4,8,16,32,64,0];
rtl_bram = [2,2,4,8,0,0,0];
PE = [1,2,4,8,16,32,64]
x = np.arange(len(PE))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_bram,width=width,label='HLS BRAM')
rect_rtl_lut = ax.bar(x+width/2,rtl_bram,width=width,label='RTL BRAM')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('BRAMs')
ax.set_xlabel('PE')
ax.set_xticks(x)
ax.set_xticklabels(PE)
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

# fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_bram2.svg', format='svg')
fig.savefig('paper_figs/res_bram2.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_lut = [156,184,236,292,429,970];
hls_ff = [211,245,311,442,710,1237];

rtl_lut = [75,79,81,86,94,106];
rtl_ff = [103,105,108,110,118,120];

IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(IFM_Ch))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_lut,width=width,label='HLS LUT')
rect_rtl_lut = ax.bar(x-width/2,hls_ff,bottom=hls_lut,width=width,label='HLS FF')
rect_hls_ff = ax.bar(x+width/2,rtl_lut,width=width,label='RTL LUT')
rect_rtl_ff = ax.bar(x+width/2,rtl_ff,bottom=rtl_lut,width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Resource count')
ax.set_xlabel('IFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(IFM_Ch)
ax.set_title("(a)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util3.svg', format='svg')
fig.savefig('paper_figs/res_util3.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
### XNOR ###
hls_bram = [2,2,2,2,2,4];
rtl_bram = [1,1,1,1,1,2];
IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(IFM_Ch))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_bram,width=width,label='HLS BRAM')
rect_rtl_lut = ax.bar(x+width/2,rtl_bram,width=width,label='RTL BRAM')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('BRAMs')
ax.set_xlabel('IFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(IFM_Ch)
ax.set_title("(a)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_bram_ifmch_xnor.svg', format='svg')
fig.savefig('paper_figs/res_bram_ifmch_xnor.eps', format='eps')
plt.show()

### STD ###
hls_bram = [2,2,2,4,0,16];
rtl_bram = [1,1,1,2,4,8];
IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(IFM_Ch))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_bram,width=width,label='HLS BRAM')
rect_rtl_lut = ax.bar(x+width/2,rtl_bram,width=width,label='RTL BRAM')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('BRAMs')
ax.set_xlabel('IFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(IFM_Ch)
ax.set_title("(c)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_bram_ifmch_std.svg', format='svg')
fig.savefig('paper_figs/res_bram_ifmch_std.eps', format='eps')
plt.show()

### BINWGT ###
hls_bram = [2,2,2,2,2,4];
rtl_bram = [1,1,1,1,1,2];
IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(IFM_Ch))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_bram,width=width,label='HLS BRAM')
rect_rtl_lut = ax.bar(x+width/2,rtl_bram,width=width,label='RTL BRAM')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('BRAMs')
ax.set_xlabel('IFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(IFM_Ch)
ax.set_title("(b)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_bram_ifmch_binwgt.svg', format='svg')
fig.savefig('paper_figs/res_bram_ifmch_binwgt.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_lut = [933,914,951,968,913,970];
hls_ff = [1231,1227,1234,1230,1234,1237];

rtl_lut = [80,91,99,100,102,106];
rtl_ff = [104,105,114,116,118,120];

OFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(OFM_Ch))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_lut,width=width,label='HLS LUT')
rect_rtl_lut = ax.bar(x-width/2,hls_ff,bottom=hls_lut,width=width,label='HLS FF')
rect_hls_ff = ax.bar(x+width/2,rtl_lut,width=width,label='RTL LUT')
rect_rtl_ff = ax.bar(x+width/2,rtl_ff,bottom=rtl_lut,width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Resource count')
ax.set_xlabel('OFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(OFM_Ch)
ax.set_title("(b)")
ax.legend(ncol=2)

## Plotting latency 
lat = [430597,861190,1722374,3444742,6889478,13778950]
ax2 = plt.twinx()
ax2.plot(lat,'kd-',linewidth=2,markersize=12,markerfacecolor='magenta',label='Latency')
ax2.set_ylim(400000,15000000)
ax2.set_ylabel('Latency')

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
# fig.savefig('paper_figs/res_util4.svg', format='svg')
# fig.savefig('paper_figs/res_util4.eps', format='eps')
plt.show()

# %%
### XNOR ###
hls_bram = [2,2,2,2,2,4];
rtl_bram = [1,1,1,1,1,2];
IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(OFM_Ch))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_bram,width=width,label='HLS BRAM')
rect_rtl_lut = ax.bar(x+width/2,rtl_bram,width=width,label='RTL BRAM')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('BRAMs')
ax.set_xlabel('OFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(OFM_Ch)
ax.set_title("(a)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_bram_ofmch_xnor.svg', format='svg')
fig.savefig('paper_figs/res_bram_ofmch_xnor.eps', format='eps')
plt.show()

### STD ###
hls_bram = [2,2,2,2,2,4];
rtl_bram = [1,1,1,1,1,2];
IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(OFM_Ch))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_bram,width=width,label='HLS BRAM')
rect_rtl_lut = ax.bar(x+width/2,rtl_bram,width=width,label='RTL BRAM')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('BRAMs')
ax.set_xlabel('OFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(IFM_Ch)
ax.set_title("(c)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_bram_ofmch_std.svg', format='svg')
fig.savefig('paper_figs/res_bram_ofmch_std.eps', format='eps')
plt.show()

### BINWGT ###
hls_bram = [2,2,2,2,2,4];
rtl_bram = [1,1,1,1,1,2];
IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(OFM_Ch))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_bram,width=width,label='HLS BRAM')
rect_rtl_lut = ax.bar(x+width/2,rtl_bram,width=width,label='RTL BRAM')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('BRAMs')
ax.set_xlabel('OFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(OFM_Ch)
ax.set_title("(b)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_bram_ofmch_binwgt.svg', format='svg')
fig.savefig('paper_figs/res_bram_ofmch_binwgt.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_dly = [2.681,2.941,2.753,2.512,2.917,2.845,2.231];
rtl_dly = [1.829,1.823,1.813,1.66,1.645,1.806,2.976];
SIMD = [1,2,4,8,16,32,64]
x = np.arange(len(SIMD))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_dly,width=width,label='HLS Delay')
rect_rtl_lut = ax.bar(x+width/2,rtl_dly,width=width,label='RTL Delay')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Total Delay (ns)')
ax.set_xlabel('SIMD')
ax.set_xticks(x)
ax.set_xticklabels(SIMD)
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

# fig.tight_layout()
plt.grid()
plt.draw()

fig.savefig('paper_figs/res_dly3.svg', format='svg')
plt.show()

# %%
hls_dly = [2.49,2.524,2.503,2.747,2.595,2.501,2.231];
rtl_dly = [1.764,1.764,1.764,1.764,1.534,2.663,2.644];
PE = [1,2,4,8,16,32,64]
x = np.arange(len(PE))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_dly,width=width,label='HLS Delay')
rect_rtl_lut = ax.bar(x+width/2,rtl_dly,width=width,label='RTL Delay')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Total Delay (ns)')
ax.set_xlabel('PE')
ax.set_xticks(x)
ax.set_xticklabels(PE)
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

# fig.tight_layout()
plt.grid()
plt.draw()

fig.savefig('paper_figs/res_dly4.svg', format='svg')
plt.show()

# %%
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,6))
KDim = [3,4,5,6,7,8,9]
x = np.arange(len(KDim))  # the label locations
width = 0.25  # the width of the bars


### XNOR
hls_kdim = pd.DataFrame({'lut': [3123,3252,3374,3545,3827,4065,4496],
                         'ff' : [1876,2327,3902,4612,5452,6413,7511],
                        'lat' : [32404,53828,78404,104980,132500,160004,186628]})

rtl_kdim = pd.DataFrame({'lut': [3731,3090,2199,2167,2202,2135,2238],
                         'ff' : [3006,2989,1472,1958,1959,1474,1991]})


rect_hls_lut = ax1.bar(x-width/2,hls_kdim['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax1.bar(x-width/2,hls_kdim['ff'],bottom=hls_kdim['lut'],width=width,label='HLS FF')
rect_hls_ff = ax1.bar(x+width/2,rtl_kdim['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax1.bar(x+width/2,rtl_kdim['ff'],bottom=rtl_kdim['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Resource count')
ax1.set_xlabel('Kernel dimensions')
ax1.set_xticks(x)
ax1.set_xticklabels(KDim)
ax1.set_title("(a)")
plt.grid()

## Plotting latency 
ax1a = ax1.twinx()
ax1a.plot(hls_kdim['lat'],'kd-',linewidth=2,markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax1a.set_ylabel('Exec. cycles')

### Binary weights
hls_kdim = pd.DataFrame({'lut': [9250,10420,10590,11683,12636,13375,15052],
                         'ff' : [5457,7223,9549,12345,15703,19589,23877],
                        'lat' : [32404,53828,78404,104980,132500,160004,186628]})

rtl_kdim = pd.DataFrame({'lut': [11639,11524,10497,10365,10501,10258,9995],
                         'ff' : [3459,3462,1971,1972,1975,1946,2532]})


rect_hls_lut = ax2.bar(x-width/2,hls_kdim['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax2.bar(x-width/2,hls_kdim['ff'],bottom=hls_kdim['lut'],width=width,label='HLS FF')
rect_hls_ff = ax2.bar(x+width/2,rtl_kdim['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax2.bar(x+width/2,rtl_kdim['ff'],bottom=rtl_kdim['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Resource count')
ax2.set_xlabel('Kernel dimensions')
ax2.set_xticks(x)
ax2.set_xticklabels(KDim)
ax2.set_title("(b)")
plt.grid()

## Plotting latency 
ax2a = ax2.twinx()
ax2a.plot(hls_kdim['lat'],'kd-',linewidth=2,markersize=6,markerfacecolor='magenta',label='Exec. cycles')
ax2a.set_ylabel('Exec. cycles')

### Standard, 4-bits
hls_lut = [26103,26548,27425,28365,28960,29815,31706];
hls_ff = [15003,16802,19381,22483,25814,29521,32475];

rtl_lut = [32739,33495,27959,27776,27909,27717,28132];
rtl_ff = [7144,7067,2891,2893,2893,2898,2912];

hls_kdim = pd.DataFrame({'lut': [26103,26548,27425,28365,28960,29815,31706],
                         'ff' : [15003,16802,19381,22483,25814,29521,32475],
                        'lat' : [32404,53828,78404,104980,132500,160004,186628]})

rtl_kdim = pd.DataFrame({'lut': [32739,33495,27959,27776,27909,27717,28132],
                         'ff' : [7144,7067,2891,2893,2893,2898,2912]})


rect_hls_lut = ax3.bar(x-width/2,hls_kdim['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax3.bar(x-width/2,hls_kdim['ff'],bottom=hls_kdim['lut'],width=width,label='HLS FF')
rect_hls_ff = ax3.bar(x+width/2,rtl_kdim['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax3.bar(x+width/2,rtl_kdim['ff'],bottom=rtl_kdim['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Resource count')
ax3.set_xlabel('Kernel dimensions')
ax3.set_xticks(x)
ax3.set_xticklabels(KDim)
ax3.set_title("(c)")
plt.grid()

## Plotting latency 
ax3a = ax3.twinx()
ax3a.plot(hls_kdim['lat'],'kd-',linewidth=2,markersize=6,markerfacecolor='magenta',label='Exec. cycles')
ax3a.set_ylabel('Exec. cycles')



fig.delaxes(ax4)
fig.tight_layout()

lines0,labels0=fig.axes[0].get_legend_handles_labels()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines0+lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.54,0.25), loc='lower left',ncol=2)

plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_kdim_final.svg', format='svg')
fig.savefig('paper_figs/res_util_kdim_final.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=8
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize

KDim = [3,4,5,6,7,8,9]
x = np.arange(len(KDim))  # the label locations
width = 0.25  # the width of the bars

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,6))

### XNOR
hls_kdim = pd.DataFrame({'dly': [3.251,2.89,3.217,3.396,3.077,2.771,2.909]})
rtl_kdim = pd.DataFrame({'dly': [1.379,1.373,1.756,1.673,1.88,1.763,1.692]});

rect_hls_dly = ax1.bar(x-width/2,hls_kdim['dly'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_kdim['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Delay (ns)')
ax1.set_xlabel('Kernel dimensions')
ax1.set_xticks(x)
ax1.set_xticklabels(KDim)
ax1.set_title("(a)")
ax1.grid()

### Binary Weights

hls_kdim = pd.DataFrame({'dly': [3.629,3.551,3.982,3.582,3.61,3.593,3.599]})
rtl_kdim = pd.DataFrame({'dly': [2.556,2.556,2.948,2.948,2.948,2.948,2.948]});

rect_hls_dly = ax2.bar(x-width/2,hls_kdim['dly'],width=width,label='HLS')
rect_rtl_dly = ax2.bar(x+width/2,rtl_kdim['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Delay (ns)')
ax2.set_xlabel('Kernel dimensions')
ax2.set_xticks(x)
ax2.set_xticklabels(KDim)
ax2.set_title("(b)")
ax2.grid()

### Standard 4-bit
hls_kdim = pd.DataFrame({'dly': [9.429,9.329,9.329,9.33,9.44,9.329,9.329]})
rtl_kdim = pd.DataFrame({'dly': [4.959,4.959,4.959,4.977,4.977,4.922,4.922]});

rect_hls_dly = ax3.bar(x-width/2,hls_kdim['dly'],width=width,label='HLS')
rect_rtl_dly = ax3.bar(x+width/2,rtl_kdim['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Delay (ns)')
ax3.set_xlabel('Kernel dimensions')
ax3.set_xticks(x)
ax3.set_xticklabels(KDim)
ax3.set_title("(c)")
ax3.grid()


fig.delaxes(ax4)

fig.tight_layout()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.75,0.25), loc='lower center',ncol=3)
plt.draw()
fig.savefig('paper_figs/res_final_kdim_dly.svg', format='svg',bbox_inches='tight')
fig.savefig('paper_figs/res_final_kdim_dly.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=8
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize

KDim = [3,4,5,6,7,8,9]
x = np.arange(len(KDim))  # the label locations
width = 0.25  # the width of the bars

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,6))

### XNOR
hls_kdim = pd.DataFrame({'bram': [32,32,32,32,32,32,32]})
rtl_kdim = pd.DataFrame({'bram': [0,0,16,16,16,16,16]});

rect_hls_dly = ax1.bar(x-width/2,hls_kdim['bram'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_kdim['bram'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Delay (ns)')
ax1.set_xlabel('Kernel dimensions')
ax1.set_xticks(x)
ax1.set_xticklabels(KDim)
ax1.set_title("(a)")
ax1.grid()

### Binary Weights

hls_kdim = pd.DataFrame({'bram': [32,32,32,32,32,32,32]})
rtl_kdim = pd.DataFrame({'bram': [0,0,16,16,16,16,16]});

rect_hls_dly = ax2.bar(x-width/2,hls_kdim['bram'],width=width,label='HLS')
rect_rtl_dly = ax2.bar(x+width/2,rtl_kdim['bram'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('BRAMs')
ax2.set_xlabel('Kernel dimensions')
ax2.set_xticks(x)
ax2.set_xticklabels(KDim)
ax2.set_title("(b)")
ax2.grid()

### Standard 4-bit
hls_kdim = pd.DataFrame({'bram': [128,128,128,128,128,128,128]})
rtl_kdim = pd.DataFrame({'bram': [0,0,64,64,64,66,66]});

rect_hls_dly = ax3.bar(x-width/2,hls_kdim['bram'],width=width,label='HLS')
rect_rtl_dly = ax3.bar(x+width/2,rtl_kdim['bram'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('BRAMs')
ax3.set_xlabel('Kernel dimensions')
ax3.set_xticks(x)
ax3.set_xticklabels(KDim)
ax3.set_title("(c)")
ax3.grid()


fig.delaxes(ax4)

fig.tight_layout()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.75,0.25), loc='lower center',ncol=3)
plt.draw()
fig.savefig('paper_figs/res_final_kdim_bram.svg', format='svg',bbox_inches='tight')
fig.savefig('paper_figs/res_final_kdim_bram.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_lut = [26103,26548,27425,28365,28960,29815,31706];
hls_ff = [15003,16802,19381,22483,25814,29521,32475];

rtl_lut = [32739,33495,27959,27776,27909,27717,28132];
rtl_ff = [7144,7067,2891,2893,2893,2898,2912];

KDim = [3,4,5,6,7,8,9]
x = np.arange(len(KDim))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_lut,width=width,label='HLS LUT')
rect_rtl_lut = ax.bar(x-width/2,hls_ff,bottom=hls_lut,width=width,label='HLS FF')
rect_hls_ff = ax.bar(x+width/2,rtl_lut,width=width,label='RTL LUT')
rect_rtl_ff = ax.bar(x+width/2,rtl_ff,bottom=rtl_lut,width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Resource count')
ax.set_xlabel('Kernel dimensions')
ax.set_xticks(x)
ax.set_xticklabels(KDim)
ax.set_title("(c)")
ax.legend(ncol=2)

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_std.svg', format='svg')
fig.savefig('paper_figs/res_util_std.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_lut 1= [9250,10420,10590,11683,12636,13375,15052];
hls_ff = [5457,7223,9549,12345,15703,19589,23877];

rtl_lut = [11639,11524,10497,10365,10501,10258,9995];
rtl_ff = [3459,3462,1971,1972,1975,1946,2532];

KDim = [3,4,5,6,7,8,9]
x = np.arange(len(KDim))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_lut,width=width,label='HLS LUT')
rect_rtl_lut = ax.bar(x-width/2,hls_ff,bottom=hls_lut,width=width,label='HLS FF')
rect_hls_ff = ax.bar(x+width/2,rtl_lut,width=width,label='RTL LUT')
rect_rtl_ff = ax.bar(x+width/2,rtl_ff,bottom=rtl_lut,width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Resource count')
ax.set_xlabel('Kernel dimensions')
ax.set_xticks(x)
ax.set_xticklabels(KDim)
ax.set_title("(b)")
ax.legend(ncol=2)

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_binwgt.svg', format='svg')
fig.savefig('paper_figs/res_util_binwgt.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_lut = [324,397,489,683,3161,2167];
hls_ff = [436,577,836,1353,2667,4604];

rtl_lut = [171,171,180,185,205,169];
rtl_ff = [137,139,180,143,145,193];

IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(IFM_Ch))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_lut,width=width,label='HLS LUT')
rect_rtl_lut = ax.bar(x-width/2,hls_ff,bottom=hls_lut,width=width,label='HLS FF')
rect_hls_ff = ax.bar(x+width/2,rtl_lut,width=width,label='RTL LUT')
rect_rtl_ff = ax.bar(x+width/2,rtl_ff,bottom=rtl_lut,width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Resource count')
ax.set_xlabel('IFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(IFM_Ch)
ax.set_title("(a)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_ifmch_std.svg', format='svg')
fig.savefig('paper_figs/res_util_ifmch_std.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_lut = [2063,2200,2233,2157,2147,2167];
hls_ff = [4606,4594,4595,4598,4601,4604];

rtl_lut = [149,156,161,164,166,169];
rtl_ff = [179,184,186,188,190,193];

OFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(OFM_Ch))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_lut,width=width,label='HLS LUT')
rect_rtl_lut = ax.bar(x-width/2,hls_ff,bottom=hls_lut,width=width,label='HLS FF')
rect_hls_ff = ax.bar(x+width/2,rtl_lut,width=width,label='RTL LUT')
rect_rtl_ff = ax.bar(x+width/2,rtl_ff,bottom=rtl_lut,width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Resource count')
ax.set_xlabel('OFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(OFM_Ch)
ax.set_title("(b)")
ax.legend(ncol=2,loc='upper center')

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_ofmch_std.svg', format='svg')
fig.savefig('paper_figs/res_util_ofmch_std.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_lut = [26768,26640,26572,26548,26670];
hls_ff = [26768,26640,26572,26548,26670];

rtl_lut = [34435,33585,33791,33634,34535];
rtl_ff = [6947,7029,6983,7110,6986];

IFM_Dim = [4,8,16,32,64]
x = np.arange(len(IFM_Dim))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_lut,width=width,label='HLS LUT')
rect_rtl_lut = ax.bar(x-width/2,hls_ff,bottom=hls_lut,width=width,label='HLS FF')
rect_hls_ff = ax.bar(x+width/2,rtl_lut,width=width,label='RTL LUT')
rect_rtl_ff = ax.bar(x+width/2,rtl_ff,bottom=rtl_lut,width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Resource count')
ax.set_xlabel('IFM dimensions')
ax.set_xticks(x)
ax.set_xticklabels(IFM_Dim)
ax.set_title("(b)")
ax.legend(ncol=2,loc='lower center')

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_ifmdim_std.svg', format='svg')
fig.savefig('paper_figs/res_util_ifmdim_std.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
hls_lut = [26768,26640,26572,26548,26670];
hls_ff = [16789,16802,16797,16802,16796];

rtl_lut = [34435,33585,33791,33634,34535];
rtl_ff = [6947,7029,6983,7110,6986];

IFMDim = [4,8,16,32,64]
x = np.arange(len(IFMDim))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_lut,width=width,label='HLS LUT')
rect_rtl_lut = ax.bar(x-width/2,hls_ff,bottom=hls_lut,width=width,label='HLS FF')
rect_hls_ff = ax.bar(x+width/2,rtl_lut,width=width,label='RTL LUT')
rect_rtl_ff = ax.bar(x+width/2,rtl_ff,bottom=rtl_lut,width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Resource count')
ax.set_xlabel('IFM dimensions')
ax.set_xticks(x)
ax.set_xticklabels(IFMDim)
ax.set_title("(c)")
ax.legend(ncol=2)

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_ifmdim_std.svg', format='svg')
fig.savefig('paper_figs/res_util_ifmdim_std.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
### XNOR ###
hls_bram = [32,32,32,32,32,32,32];
rtl_bram = [0,0,16,16,16,16,16];
KDim = [3,4,5,6,7,8,9]
x = np.arange(len(KDim))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_bram,width=width,label='HLS BRAM')
rect_rtl_lut = ax.bar(x+width/2,rtl_bram,width=width,label='RTL BRAM')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('BRAMs')
ax.set_xlabel('Kernel dimensions')
ax.set_xticks(x)
ax.set_xticklabels(KDim)
ax.set_title("(a)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_bram_kdim_xnor.svg', format='svg')
fig.savefig('paper_figs/res_bram_kdim_xnor.eps', format='eps')
plt.show()

### STD ###
hls_bram = [128,128,128,128,128,128,128];
rtl_bram = [0,0,64,64,64,64,64];
KDim = [3,4,5,6,7,8,9]
x = np.arange(len(KDim))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_bram,width=width,label='HLS BRAM')
rect_rtl_lut = ax.bar(x+width/2,rtl_bram,width=width,label='RTL BRAM')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('BRAMs')
ax.set_xlabel('Kernel dimensions')
ax.set_xticks(x)
ax.set_xticklabels(KDim)
ax.set_title("(c)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_bram_kdim_std.svg', format='svg')
fig.savefig('paper_figs/res_bram_kdim_std.eps', format='eps')
plt.show()

### BINWGT ###
hls_bram = [32,32,32,32,32,32,32];
rtl_bram = [0,0,16,16,16,16,16];
KDim = [3,4,5,6,7,8,9]
x = np.arange(len(KDim))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_bram,width=width,label='HLS BRAM')
rect_rtl_lut = ax.bar(x+width/2,rtl_bram,width=width,label='RTL BRAM')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('BRAMs')
ax.set_xlabel('Kernel dimensions')
ax.set_xticks(x)
ax.set_xticklabels(KDim)
ax.set_title("(b)")
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_bram_kdim_binwgt.svg', format='svg')
fig.savefig('paper_figs/res_bram_kdim_binwgt.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
### IFM Channels ###
hls_dly = [2.5,2.422,2.567,2.561,2.589,2.598];
rtl_dly = [1.399,1.4,1.406,1.408,1.415,1.42];
IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(IFM_Ch))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_dly,width=width,label='HLS Delay')
rect_rtl_lut = ax.bar(x+width/2,rtl_dly,width=width,label='RTL Delay')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Total Delay (ns)')
ax.set_xlabel('IFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(IFM_Ch)
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

# fig.tight_layout()
plt.grid()
plt.draw()

fig.savefig('paper_figs/res_dly2.svg', format='svg')
plt.show()

### OFM Channels ###
hls_dly = [2.458,2.562,2.486,2.604,2.715,2.598];
rtl_dly = [1.367,1.405,1.333,1.418,1.419,1.42];
OFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(OFM_Ch))  # the label locations
width = 0.25  # the width of the bars
fig, ax = plt.subplots()
rect_hls_lut = ax.bar(x-width/2,hls_dly,width=width,label='HLS Delay')
rect_rtl_lut = ax.bar(x+width/2,rtl_dly,width=width,label='RTL Delay')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Total Delay (ns)')
ax.set_xlabel('OFM Channels')
ax.set_xticks(x)
ax.set_xticklabels(OFM_Ch)
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

# fig.tight_layout()
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_dly1.svg', format='svg')
plt.show()

### IFM Dimensions


### Kernel Dimensions

# %%
fontsize=8
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize

IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(IFM_Ch))  # the label locations
width = 0.25  # the width of the bars

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,6))

### IFM Channels
hls_ifm = pd.DataFrame({'lut': [156,184,236,292,429,970],
                    'ff': [211,245,311,442,710,1237],
                   'lat':[430595,861187,1722371,3444739,6889475,13778947]})

rtl_ifm = pd.DataFrame({'lut': [75,79,81,86,94,106],
                    'ff': [103,105,108,110,118,120]});

rect_hls_lut = ax1.bar(x-width/2,hls_ifm['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax1.bar(x-width/2,hls_ifm['ff'],bottom=hls_ifm['lut'],width=width,label='HLS FF')
rect_hls_ff = ax1.bar(x+width/2,rtl_ifm['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax1.bar(x+width/2,rtl_ifm['ff'],bottom=rtl_ifm['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Resource count')
ax1.set_xlabel('IFM channels')
ax1.set_xticks(x)
ax1.set_xticklabels(IFM_Ch)
ax1.set_title("(a)")
ax1.grid()

## Plotting latency 
ax1a = ax1.twinx()
ax1a.plot(hls_ifm['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
ax1a.set_ylim(400000,15000000)
ax1a.set_ylabel('Exec. cycles')

### OFM Channels
hls_ofm = pd.DataFrame({'lut': [933,914,951,968,913,970],
                     'ff' : [1231,1227,1234,1230,1234,1237],
                     'lat': [430597,861190,1722374,3444742,6889478,13778950]})

rtl_ofm = pd.DataFrame({ 'lut': [80,91,99,100,102,106],
                    'ff' : [104,105,114,116,118,120]})                    

OFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(OFM_Ch))  # the label locations
width = 0.25  # the width of the bars

rect_hls_lut = ax2.bar(x-width/2,hls_ofm['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax2.bar(x-width/2,hls_ofm['ff'],bottom=hls_ofm['lut'],width=width,label='HLS FF')
rect_hls_ff = ax2.bar(x+width/2,rtl_ofm['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax2.bar(x+width/2,rtl_ofm['ff'],bottom=rtl_ofm['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Resource count')
ax2.set_xlabel('OFM channels')
ax2.set_xticks(x)
ax2.set_xticklabels(OFM_Ch)
ax2.set_title("(b)")
ax2.grid()

## Plotting latency 
ax2a = ax2.twinx()
ax2a.plot(hls_ofm['lat'],'kd-',linewidth=2,markersize=6,markerfacecolor='magenta',label='Exec. cycles')
ax2a.set_ylim(400000,15000000)
ax2a.set_ylabel('Exec. cycles')


### Processing Elements
hls_pe = pd.DataFrame({'lut':[591,707,977,1490,2619,4845,11327],
                       'ff': [1391,1455,1587,1856,2390,3622,9655],
                      'lat': [25604,12804,6404,3204,1604,804,404]})

rtl_pe = pd.DataFrame({'lut': [282,428,718,1301,3280,5922,11759],
                       'ff' : [201,300,500,902,2942,4223,8541]});

PE = [1,2,4,8,16,32,64]
x = np.arange(len(PE))  # the label locations
width = 0.25  # the width of the bars

rect_hls_lut = ax3.bar(x-width/2,hls_pe['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax3.bar(x-width/2,hls_pe['ff'],bottom=hls_pe['lut'],width=width,label='HLS FF')
rect_hls_ff = ax3.bar(x+width/2,rtl_pe['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax3.bar(x+width/2,rtl_pe['ff'],bottom=rtl_pe['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Resource count')
ax3.set_xlabel('Processing elements (PEs)')
ax3.set_xticks(x)
ax3.set_xticklabels(PE)
ax3.set_title("(c)")
ax3.grid()

### Latency
ax3a = ax3.twinx()
ax3a.plot(hls_pe['lat'],'kd-',linewidth=2,markersize=6,markerfacecolor='magenta',label='Exec. cycles')
ax3a.set_ylim(300,30000)
ax3a.set_ylabel('Exec. cycles')

### SIMD

hls_simd = pd.DataFrame({'lut' : [2773,2467,2231,3792,6139,8572,11486],
                         'ff' : [3273,3275,3277,3511,5301,7440,9652],
                         'lat' : [25603,12803,6403,3203,1604,804,404]})

rtl_simd = pd.DataFrame({'lut': [1140,1170,1423,1717,3411,5075,11676],
                         'ff' : [2224,2286,2352,2428,3485,4727,8084]})

SIMD = [1,2,4,8,16,32,64]
x = np.arange(len(SIMD))  # the label locations
width = 0.25  # the width of the bars

rect_hls_lut = ax4.bar(x-width/2,hls_simd['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax4.bar(x-width/2,hls_simd['ff'],bottom=hls_simd['lut'],width=width,label='HLS FF')
rect_hls_ff = ax4.bar(x+width/2,rtl_simd['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax4.bar(x+width/2,rtl_simd['ff'],bottom=rtl_simd['lut'],width=width,label='RTL FF')
# rects2 = ax.bar(x + width/2, rtl_exec, width, label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax4.set_ylabel('Resource count')
ax4.set_xlabel('SIMDs')
ax4.set_xticks(x)
ax4.set_xticklabels(SIMD)
ax4.set_title('(d)')
ax4.grid()

### Latency
ax4a = ax4.twinx()
ax4a.plot(hls_simd['lat'],'kd-',linewidth=2,markersize=6,markerfacecolor='magenta',label='Exec. cycles')
ax4a.set_ylim(300,30000)
ax4a.set_ylabel('Exec. cycles')

fig.tight_layout()
lines0,labels0=fig.axes[0].get_legend_handles_labels()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines0+lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.5,-0.1), loc='lower center',ncol=3)
plt.draw()
fig.savefig('paper_figs/res_final.svg', format='svg',bbox_inches='tight')
fig.savefig('paper_figs/res_final.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
### HeatMap
### for LUTs
pe = ['2','4','8','16','32','64']
simd = ['2','4','8','16','32','64']

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.set_facecolor([235/255,235/255,243/255,255/255])

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.set_facecolor([235/255,235/255,243/255,255/255])

hls_lut_pe = pd.DataFrame({'simd-2':[2009,2072,2275,2493,4011,5689],
                       'simd-4':[1714,1868,2250,3062,4752,8169],
                       'simd-8':[1799,2219,3064,4731,8141,14613],
                       'simd-16':[2143,2942,4548,7781,13822,26682],
                       'simd-32':[2919,4494,7659,13607,25626,50231],
                       'simd-64':[4517,7540,13577,25792,50106,107320]
                      })

rtl_lut_pe = pd.DataFrame({'simd-2':[184,371,693,1037,2184,4320],
                       'simd-4':[286,522,1069,1943,4041,8031],
                       'simd-8':[569,991,1847,3564,7178,14350],
                       'simd-16':[994,1848,3561,6996,14081,27932],
                       'simd-32':[1883,3538,6848,13599,31072,57430],
                       'simd-64':[3656,7039,13237,31608,58306,112998]
                      })

lut_pe_diff = pd.DataFrame({'2': hls_lut_pe['simd-2']-rtl_lut_pe['simd-2'],
                            '4': hls_lut_pe['simd-4']-rtl_lut_pe['simd-4'],
                            '8': hls_lut_pe['simd-8']-rtl_lut_pe['simd-8'],
                            '16': hls_lut_pe['simd-16']-rtl_lut_pe['simd-16'],
                            '32': hls_lut_pe['simd-32']-rtl_lut_pe['simd-32'],
                            '64': hls_lut_pe['simd-64']-rtl_lut_pe['simd-64']})
                           
hls_lut_simd = pd.DataFrame({'pe-2':[184,286,569,994,1883,3656,],
                             'pe-4':[2072,1867,2219,2942,4494,7540],
                             'pe-8':[2275,2247,3064,4548,7659,13577],
                             'pe-16':[2493,3062,4731,7781,13607,25792],
                             'pe-32':[4011,4755,8141,13822,25626,50106],
                             'pe-64':[5688,8090,14613,26682,50231,107315]
                            })

rtl_lut_simd = pd.DataFrame({'pe-2':[169,349,540,989,1904,3647],
                             'pe-4':[371,522,991,1848,3538,7039],
                             'pe-8':[693,1069,1847,3561,6848,13237],
                             'pe-16':[1037,1943,3564,6996,13599,31608],
                             'pe-32':[2184,4041,7178,14081,31072,58306],
                             'pe-64':[4320,8031,14350,27932,57430,112995]
                            })

lut_simd_diff = pd.DataFrame({'2': hls_lut_simd['pe-2']-rtl_lut_simd['pe-2'],
                            '4': hls_lut_simd['pe-4']-rtl_lut_simd['pe-4'],
                            '8': hls_lut_simd['pe-8']-rtl_lut_simd['pe-8'],
                            '16': hls_lut_simd['pe-16']-rtl_lut_simd['pe-16'],
                            '32': hls_lut_simd['pe-32']-rtl_lut_simd['pe-32'],
                            '64': hls_lut_simd['pe-64']-rtl_lut_simd['pe-64']})


lut_simd_diff = lut_simd_diff.set_index([pd.Index([2,4,8,16,32,64])])

### Flip Flops
hls_ff_pe = pd.DataFrame({'simd-2':[4568,4515,4740,5058,5313,6377],
                       'simd-4':[4698,4695,5037,5577,6499,7629],
                       'simd-8':[4981,5128,5634,6631,8286,9559],
                       'simd-16':[5249,5868,6819,8711,8383,13970],
                       'simd-32':[6652,7335,9258,10406,12104,23268],
                       'simd-64':[8769,9182,10926,16919,19915,59430]
                      })

rtl_ff_pe = pd.DataFrame({'simd-2':[223,352,409,327,501,2057],
                       'simd-4':[336,621,796,551,837,3498],
                       'simd-8':[624,1131,1568,1002,1512,1101],
                       'simd-16':[1335,2338,3066,1915,1709,1976],
                       'simd-32':[3262,5513,6942,3015,7899,12077],
                       'simd-64':[5512,9998,3998,5193,14319,23936]
                      })

ff_pe_diff = pd.DataFrame({'2': hls_ff_pe['simd-2']-rtl_ff_pe['simd-2'],
                            '4': hls_ff_pe['simd-4']-rtl_ff_pe['simd-4'],
                            '8': hls_ff_pe['simd-8']-rtl_ff_pe['simd-8'],
                            '16': hls_ff_pe['simd-16']-rtl_ff_pe['simd-16'],
                            '32': hls_ff_pe['simd-32']-rtl_ff_pe['simd-32'],
                            '64': hls_ff_pe['simd-64']-rtl_ff_pe['simd-64']})
                           
hls_ff_simd = pd.DataFrame({'pe-2':[4599,5113,4858,5281,6036,7109],
                             'pe-4':[5008,5507,5240,5897,6967,9273],
                             'pe-8':[4948,5472,6486,7131,8955,10509],
                             'pe-16':[5809,6784,8268,9601,11002,16093],
                             'pe-32':[7369,9400,10572,15127,19786,27661],
                             'pe-64':[9115,11711,16685,24966,34289,60670]
                            })

rtl_ff_simd = pd.DataFrame({'pe-2':[193,201,356,386,469,2039],
                             'pe-4':[276,343,716,668,773,3781],
                             'pe-8':[503,629,1336,1234,1383,907],
                             'pe-16':[829,1207,2600,2376,1432,5860],
                             'pe-32':[3262,3386,6616,2823,7894,12077],
                             'pe-64':[5512,6068,3984,9008,14026,23931]
                            })

ff_simd_diff = pd.DataFrame({'2': hls_ff_simd['pe-2']-rtl_ff_simd['pe-2'],
                            '4': hls_ff_simd['pe-4']-rtl_ff_simd['pe-4'],
                            '8': hls_ff_simd['pe-8']-rtl_ff_simd['pe-8'],
                            '16': hls_ff_simd['pe-16']-rtl_ff_simd['pe-16'],
                            '32': hls_ff_simd['pe-32']-rtl_ff_simd['pe-32'],
                            '64': hls_ff_simd['pe-64']-rtl_ff_simd['pe-64']})

ff_simd_diff_perc = pd.DataFrame({'2': (hls_ff_simd['pe-2']-rtl_ff_simd['pe-2'])/rtl_ff_simd['pe-2']*100,
                            '4': hls_ff_simd['pe-4']-rtl_ff_simd['pe-4']/rtl_ff_simd['pe-4']*100,
                            '8': hls_ff_simd['pe-8']-rtl_ff_simd['pe-8']/rtl_ff_simd['pe-8']*100,
                            '16': hls_ff_simd['pe-16']-rtl_ff_simd['pe-16']/rtl_ff_simd['pe-16']*100,
                            '32': hls_ff_simd['pe-32']-rtl_ff_simd['pe-32']/rtl_ff_simd['pe-32']*100,
                            '64': hls_ff_simd['pe-64']-rtl_ff_simd['pe-64']/rtl_ff_simd['pe-64']*100})

fontsize=32
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
ff_simd_diff = ff_simd_diff.set_index([pd.Index([2,4,8,16,32,64])])
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharey=True,figsize=(10,6))
fig.delaxes(ax3)
fig.delaxes(ax4)
# sns.set(font_scale=1.0)
s1=sns.heatmap(lut_simd_diff,ax=ax1)
s1.invert_yaxis()
s1.set(xlabel='Processing elements (PEs)', ylabel='SIMDs', title='(a)')
s2=sns.heatmap(ff_simd_diff,ax=ax2)
s2.invert_yaxis()
s2.set(xlabel='Processing elements (PEs)', title='(b)')
plt.draw()
fig.savefig('paper_figs/pe_simd_heatmap.eps', format='eps',bbox_inches='tight')
plt.show()

# %%
print(ff_simd_diff_perc)
# Out:
#              2       4        8       16       32       64
# 0  2282.901554  4908.0   4848.0   5709.0   7269.0   9015.0
# 1  2443.781095  5407.0   5372.0   6684.0   9300.0  11611.0
# 2  1264.606742  5140.0   6386.0   8168.0  10472.0  16585.0
# 3  1268.134715  5797.0   7031.0   9501.0  15027.0  24866.0
# 4  1186.993603  6867.0   8855.0  10902.0  19686.0  34189.0
# 5   248.651300  9173.0  10409.0  15993.0  27561.0  60570.0

# %%
fontsize=12
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

### IFM Dimension Plot with latency

### XNOR
hls_ifmd = pd.DataFrame({'lut':[3240,3257,3252,3252,3247],
                    'ff' :[2318,2322,2325,2327,2329],
                    'lat':[68,1604,10820,53828,238148]})

rtl_ifmd = pd.DataFrame({'lut':[3090,3090,3090,3090,3090],
                    'ff' :[2989,2989,2989,2989,2989]})

IFM_Dim = [4,8,16,32,64]
x = np.arange(len(IFM_Dim))  # the label locations
width = 0.25  # the width of the bars

rect_hls_lut = ax1.bar(x-width/2,hls_ifmd['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax1.bar(x-width/2,hls_ifmd['ff'],bottom=hls_ifmd['lut'],width=width,label='HLS FF')
rect_hls_ff = ax1.bar(x+width/2,rtl_ifmd['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax1.bar(x+width/2,rtl_ifmd['ff'],bottom=rtl_ifmd['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Resource count')
ax1.set_xlabel('IFM dimensions')
ax1.set_xticks(x)
ax1.set_xticklabels(IFM_Dim)
ax1.set_title("(a)")

## Plotting latency 
ax1a = ax1.twinx()
ax1a.plot(hls_ifmd['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax1a.set_ylabel('Exec. cycles')

### Binary Weight
hls_ifmd = pd.DataFrame({'lut':[10795,10372,10387,10420,10407],
                    'ff' :[7224,7237,7225,7223,7247],
                    'lat':[68,1604,10820,53828,238148]})

rtl_ifmd = pd.DataFrame({'lut':[11524,11526,11526,11526,11524],
                    'ff' :[3462,3465,3465,3464,3462,]})

IFM_Dim = [4,8,16,32,64]
x = np.arange(len(IFM_Dim))  # the label locations
width = 0.25  # the width of the bars

rect_hls_lut = ax2.bar(x-width/2,hls_ifmd['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax2.bar(x-width/2,hls_ifmd['ff'],bottom=hls_ifmd['lut'],width=width,label='HLS FF')
rect_hls_ff = ax2.bar(x+width/2,rtl_ifmd['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax2.bar(x+width/2,rtl_ifmd['ff'],bottom=rtl_ifmd['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Resource count')
ax2.set_xlabel('IFM dimensions')
ax2.set_xticks(x)
ax2.set_xticklabels(IFM_Dim)
ax2.set_title("(b)")

## Plotting latency 
ax2a = ax2.twinx()
ax2a.plot(hls_ifmd['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax2a.set_ylabel('Exec. cycles')


### 4-bit
hls_ifmd = pd.DataFrame({'lut':[26225,26201,26198,26199,26226],
                    'ff' :[12734,12734,12747,12749,12745],
                    'lat':[69,1605,10821,53829,238149]})

rtl_ifmd = pd.DataFrame({'lut':[33372,33697,32820,33955,31601],
                    'ff' :[6949,6949,7030,6949,7167]})

IFM_Dim = [4,8,16,32,64]
x = np.arange(len(IFM_Dim))  # the label locations
width = 0.25  # the width of the bars

rect_hls_lut = ax3.bar(x-width/2,hls_ifmd['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax3.bar(x-width/2,hls_ifmd['ff'],bottom=hls_ifmd['lut'],width=width,label='HLS FF')
rect_hls_ff = ax3.bar(x+width/2,rtl_ifmd['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax3.bar(x+width/2,rtl_ifmd['ff'],bottom=rtl_ifmd['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Resource count')
ax3.set_xlabel('IFM dimensions')
ax3.set_xticks(x)
ax3.set_xticklabels(IFM_Dim)
ax3.set_title("(c)")

## Plotting latency 
ax3a = ax3.twinx()
ax3a.plot(hls_ifmd['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax3a.set_ylim(400000,15000000)
ax3a.set_ylabel('Exec. cycles')

fig.delaxes(ax4)
fig.tight_layout()

lines0,labels0=fig.axes[0].get_legend_handles_labels()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines0+lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.54,0.25), loc='lower left',ncol=2)

plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_ifmdim_final.svg', format='svg')
fig.savefig('paper_figs/res_util_ifmdim_final.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=8
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize


fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharey=True,figsize=(10,6))

### IFM Channels
IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(IFM_Ch))  # the label locations
width = 0.25  # the width of the bars
hls_ifm = pd.DataFrame({'dly': [2.5,2.422,2.567,2.561,2.589,2.598]})
rtl_ifm = pd.DataFrame({'dly': [1.399,1.4,1.406,1.408,1.415,1.42]});

rect_hls_dly = ax1.bar(x-width/2,hls_ifm['dly'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_ifm['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Delay (ns)')
ax1.set_xlabel('IFM channels')
ax1.set_xticks(x)
ax1.set_xticklabels(IFM_Ch)
ax1.set_title("(a)")
ax1.grid()

### OFM Channels
OFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(OFM_Ch))  # the label locations
width = 0.25  # the width of the bars

hls_ofm = pd.DataFrame({'dly': [2.458,2.562,2.486,2.604,2.715,2.598]})
rtl_ofm = pd.DataFrame({'dly': [1.367,1.405,1.333,1.418,1.419,1.42]});

rect_hls_dly = ax2.bar(x-width/2,hls_ofm['dly'],width=width,label='HLS')
rect_rtl_dly = ax2.bar(x+width/2,rtl_ofm['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Delay (ns)')
ax2.set_xlabel('OFM channels')
ax2.set_xticks(x)
ax2.set_xticklabels(OFM_Ch)
ax2.set_title("(b)")
ax2.grid()

### Processing Elements
PE = [1,2,4,8,16,32,64]
x = np.arange(len(PE))  # the label locations
width = 0.25  # the width of the bars

hls_pe = pd.DataFrame({'dly':[2.49,2.524,2.503,2.747,2.595,2.501,2.231]})

rtl_pe = pd.DataFrame({'dly': [1.764,1.764,1.764,1.764,1.534,2.663,2.644]});


rect_hls_dly = ax3.bar(x-width/2,hls_pe['dly'],width=width,label='HLS')
rect_rtl_dly = ax3.bar(x+width/2,rtl_pe['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Delay (ns)')
ax3.set_xlabel('Processing elements (PEs)')
ax3.set_xticks(x)
ax3.set_xticklabels(PE)
ax3.set_title("(c)")
ax3.grid()


### SIMD

SIMD = [1,2,4,8,16,32,64]
x = np.arange(len(SIMD))  # the label locations
width = 0.25  # the width of the bars

hls_simd = pd.DataFrame({'dly' : [2.681,2.941,2.753,2.512,2.917,2.845,2.231]})

rtl_simd = pd.DataFrame({'dly': [1.829,1.823,1.813,1.66,1.645,1.806,2.976]})

rect_hls_dly = ax4.bar(x-width/2,hls_simd['dly'],width=width,label='HLS')
rect_rtl_dly = ax4.bar(x+width/2,rtl_simd['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax4.set_ylabel('Delay (ns)')
ax4.set_xlabel('SIMDs')
ax4.set_xticks(x)
ax4.set_xticklabels(SIMD)
ax4.set_title('(d)')
ax4.grid()

fig.tight_layout()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.5,-0.1), loc='lower center',ncol=3)
plt.draw()
fig.savefig('paper_figs/res_final_dly.svg', format='svg',bbox_inches='tight')
fig.savefig('paper_figs/res_final_dly.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
### BRAMs for 1-bit
del ax1,ax2,ax3,ax4,ax5,fig
fig,((ax1,ax2,x1),(ax3,ax4,x2),(ax5,x3,x4)) = plt.subplots(nrows=3,ncols=3,figsize=(10,6))
fontsize=10
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize

ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.set_facecolor([235/255,235/255,243/255,255/255])

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.set_facecolor([235/255,235/255,243/255,255/255])

ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.set_facecolor([235/255,235/255,243/255,255/255])

ax4.spines['top'].set_visible(False)
ax4.spines['right'].set_visible(False)
ax4.spines['bottom'].set_visible(False)
ax4.spines['left'].set_visible(False)
ax4.set_facecolor([235/255,235/255,243/255,255/255])

ax5.spines['top'].set_visible(False)
ax5.spines['right'].set_visible(False)
ax5.spines['bottom'].set_visible(False)
ax5.spines['left'].set_visible(False)
ax5.set_facecolor([235/255,235/255,243/255,255/255])

### IFM Channels
IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(IFM_Ch))  # the label locations
width = 0.25  # the width of the bars
hls_ifm = pd.DataFrame({'bram': [2,2,2,2,2,4]})
rtl_ifm = pd.DataFrame({'bram': [1,1,1,1,1,2]});

rect_hls_dly = ax1.bar(x-width/2,hls_ifm['bram'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_ifm['bram'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('BRAMs',fontsize=fontsize)
ax1.set_xlabel('IFM channels',fontsize=fontsize)
ax1.set_xticks(x)
ax1.set_xticklabels(IFM_Ch,fontsize=fontsize)
ax1.set_title("(a)",fontsize=fontsize)
plt.grid()

### OFM Channels
OFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(OFM_Ch))  # the label locations
width = 0.25  # the width of the bars

hls_ofm = pd.DataFrame({'bram': [2,2,2,2,2,4]})
rtl_ofm = pd.DataFrame({'bram': [1,1,1,1,1,2]});

rect_hls_dly = ax2.bar(x-width/2,hls_ofm['bram'],width=width,label='HLS')
rect_rtl_dly = ax2.bar(x+width/2,rtl_ofm['bram'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('BRAMs',fontsize=fontsize)
ax2.set_xlabel('OFM channels',fontsize=fontsize)
ax2.set_xticks(x)
ax2.set_xticklabels(OFM_Ch,fontsize=fontsize)
ax2.set_title("(b)",fontsize=fontsize)
plt.grid()

### Processing Elements
PE = [1,2,4,8,16,32,64]
x = np.arange(len(PE))  # the label locations
width = 0.25  # the width of the bars

hls_pe = pd.DataFrame({'bram':[4,4,8,16,32,64,0]})
rtl_pe = pd.DataFrame({'bram': [2,2,4,8,0,0,0]});

rect_hls_dly = ax3.bar(x-width/2,hls_pe['bram'],width=width,label='HLS')
rect_rtl_dly = ax3.bar(x+width/2,rtl_pe['bram'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('BRAMs',fontsize=fontsize)
ax3.set_xlabel('Processing elements (PEs)',fontsize=fontsize)
ax3.set_xticks(x)
ax3.set_xticklabels(PE,fontsize=fontsize)
ax3.set_title("(c)",fontsize=fontsize)
plt.grid()


### SIMD
SIMD = [1,2,4,8,16,32,64]
x = np.arange(len(SIMD))  # the label locations
width = 0.25  # the width of the bars

hls_simd = pd.DataFrame({'bram' : [64,64,64,33,0,0,0]})
rtl_simd = pd.DataFrame({'bram': [32,32,32,32,0,0,0]})

rect_hls_dly = ax4.bar(x-width/2,hls_simd['bram'],width=width,label='HLS')
rect_rtl_dly = ax4.bar(x+width/2,rtl_simd['bram'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax4.set_ylabel('BRAMs',fontsize=fontsize)
ax4.set_xlabel('SIMDs',fontsize=fontsize)
ax4.set_xticks(x)
ax4.set_xticklabels(SIMD,fontsize=fontsize)
ax4.set_title('(d)',fontsize=fontsize)
plt.grid()
IFM_Dim = [4,8,16,32,64]
x = np.arange(len(IFM_Dim))  # the label locations
width = 0.25  # the width of the bars

### IFM Dimensions - XNOR
hls_ifmd = pd.DataFrame({'bram': [32,32,32,32,32]})
rtl_ifmd = pd.DataFrame({'bram': [0,0,0,0,0]});

rect_hls_dly = ax5.bar(x-width/2,hls_ifmd['bram'],width=width,label='HLS')
rect_rtl_dly = ax5.bar(x+width/2,rtl_ifmd['bram'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax5.set_ylabel('BRAMs',fontsize=fontsize)
ax5.set_xlabel('IFM dimensions',fontsize=fontsize)
ax5.set_xticks(x)
ax5.set_xticklabels(IFM_Dim,fontsize=fontsize)
ax5.set_title("(e)",fontsize=fontsize)
plt.grid()

fig.delaxes(x1)
fig.delaxes(x2)
fig.delaxes(x3)
fig.delaxes(x4)

fig.tight_layout()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.525,0.15), loc='lower center',ncol=3)
plt.draw()
fig.savefig('paper_figs/res_final_bram.svg', format='svg',bbox_inches='tight')
fig.savefig('paper_figs/res_final_bram.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=8
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize

IFM_Dim = [4,8,16,32,64]
x = np.arange(len(IFM_Dim))  # the label locations
width = 0.25  # the width of the bars

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,6))

### XNOR
hls_ifmd = pd.DataFrame({'dly': [2.73,2.899,2.899,2.89,2.73]})
rtl_ifmd = pd.DataFrame({'dly': [1.373,1.373,1.373,1.373,1.373]});

rect_hls_dly = ax1.bar(x-width/2,hls_ifmd['dly'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_ifmd['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Delay (ns)')
ax1.set_xlabel('IFM dimensions')
ax1.set_xticks(x)
ax1.set_xticklabels(IFM_Dim)
ax1.set_title("(a)")
ax1.grid()

### Binary Weights

hls_ifmd = pd.DataFrame({'dly': [3.734,3.562,3.825,3.551,3.578]})
rtl_ifmd = pd.DataFrame({'dly': [2.556,2.556,2.556,2.556,2.556]});

rect_hls_dly = ax2.bar(x-width/2,hls_ifmd['dly'],width=width,label='HLS')
rect_rtl_dly = ax2.bar(x+width/2,rtl_ifmd['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Delay (ns)')
ax2.set_xlabel('IFM dimensions')
ax2.set_xticks(x)
ax2.set_xticklabels(IFM_Dim)
ax2.set_title("(b)")
ax2.grid()

### Standard 4-bit
hls_ifmd = pd.DataFrame({'dly': [9.329,9.329,9.329,9.329,9.329]})
rtl_ifmd = pd.DataFrame({'dly': [4.959,4.959,4.959,4.959,4.959]});

rect_hls_dly = ax3.bar(x-width/2,hls_ifmd['dly'],width=width,label='HLS')
rect_rtl_dly = ax3.bar(x+width/2,rtl_ifmd['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Delay (ns)')
ax3.set_xlabel('IFM dimensions')
ax3.set_xticks(x)
ax3.set_xticklabels(IFM_Dim)
ax3.set_title("(c)")
ax3.grid()


fig.delaxes(ax4)

fig.tight_layout()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.75,0.25), loc='lower center',ncol=3)
plt.draw()
fig.savefig('paper_figs/res_final_ifmdim_dly.svg', format='svg',bbox_inches='tight')
fig.savefig('paper_figs/res_final_ifmdim_dly.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=8
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize

IFM_Dim = [4,8,16,32,64]
x = np.arange(len(IFM_Dim))  # the label locations
width = 0.25  # the width of the bars

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,6))

### XNOR
hls_ifmd = pd.DataFrame({'bram': [32,32,32,32,32]})
rtl_ifmd = pd.DataFrame({'bram': [0,0,0,0,0]});

rect_hls_dly = ax1.bar(x-width/2,hls_ifmd['bram'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_ifmd['bram'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('BRAMs')
ax1.set_xlabel('IFM dimensions')
ax1.set_xticks(x)
ax1.set_xticklabels(IFM_Dim)
ax1.set_title("(a)")
ax1.grid()

### Binary Weights

hls_ifmd = pd.DataFrame({'bram': [32,32,32,32,32]})
rtl_ifmd = pd.DataFrame({'bram': [0,0,0,0,0]});

rect_hls_dly = ax2.bar(x-width/2,hls_ifmd['bram'],width=width,label='HLS')
rect_rtl_dly = ax2.bar(x+width/2,rtl_ifmd['bram'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('BRAMs')
ax2.set_xlabel('IFM dimensions')
ax2.set_xticks(x)
ax2.set_xticklabels(IFM_Dim)
ax2.set_title("(b)")
ax2.grid()

### Standard 4-bit
hls_ifmd = pd.DataFrame({'bram': [128,128,128,128,128]})
rtl_ifmd = pd.DataFrame({'bram': [0,0,0,0,0]});

rect_hls_dly = ax3.bar(x-width/2,hls_ifmd['bram'],width=width,label='HLS')
rect_rtl_dly = ax3.bar(x+width/2,rtl_ifmd['bram'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('BRAMs')
ax3.set_xlabel('IFM dimensions')
ax3.set_xticks(x)
ax3.set_xticklabels(IFM_Dim)
ax3.set_title("(c)")
ax3.grid()


fig.delaxes(ax4)

fig.tight_layout()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.75,0.25), loc='lower center',ncol=3)
plt.draw()
fig.savefig('paper_figs/res_final_ifmdim_bram.svg', format='svg',bbox_inches='tight')
fig.savefig('paper_figs/res_final_ifmdim_bram.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
### HeatMap
### for Delays
pe = ['2','4','8','16','32','64']
simd = ['2','4','8','16','32','64']
hls_dly_pe = pd.DataFrame({'simd-2':[7.384,7.422,7.422,7.829,7.585,7.585],
                       'simd-4':[7.972,8.052,6.401,7.286,6.482,9.374],
                       'simd-8':[6.549,6.549,6.549,6.549,6.549,7.063],
                       'simd-16':[6.575,6.575,6.575,6.575,7.795,7.779],
                       'simd-32':[8.72,6.53,6.53,7.967,7.779,7.591],
                       'simd-64':[8.23,8.23,8.977,8.908,8.911,8.977]
                      })

rtl_dly_pe = pd.DataFrame({'simd-2':[4.924,4.924,4.924,4.924,4.918,4.923],
                       'simd-4':[4.923,4.923,4.918,4.918,4.918,4.923],
                       'simd-8':[4.982,4.982,4.982,4.982,4.982,4.982],
                       'simd-16':[4.977,4.977,4.977,4.977,4.977,4.977],
                       'simd-32':[4.959,4.959,4.959,4.959,4.959,4.959],
                       'simd-64':[4.959,4.959,4.959,4.959,4.959,4.959]
                      })

dly_pe_diff = pd.DataFrame({'2': hls_dly_pe['simd-2']-rtl_dly_pe['simd-2'],
                            '4': hls_dly_pe['simd-4']-rtl_dly_pe['simd-4'],
                            '8': hls_dly_pe['simd-8']-rtl_dly_pe['simd-8'],
                            '16': hls_dly_pe['simd-16']-rtl_dly_pe['simd-16'],
                            '32': hls_dly_pe['simd-32']-rtl_dly_pe['simd-32'],
                            '64': hls_dly_pe['simd-64']-rtl_dly_pe['simd-64']})
                           
hls_dly_simd = pd.DataFrame({'pe-2':[7.384,7.972,6.549,6.575,8.72,8.23],
                             'pe-4':[7.422,8.052,6.549,6.575,6.53,8.23],
                             'pe-8':[7.422,6.401,6.549,6.575,6.53,8.977],
                             'pe-16':[7.829,7.286,6.549,6.575,7.967,8.908],
                             'pe-32':[7.585,6.482,6.549,7.795,7.779,8.911],
                             'pe-64':[7.586,9.374,7.063,7.779,7.591,8.977]
                            })

rtl_dly_simd = pd.DataFrame({'pe-2':[4.924,4.923,4.982,4.977,4.959,4.959],
                             'pe-4':[4.924,4.923,4.982,4.977,4.959,4.959],
                             'pe-8':[4.924,4.918,4.982,4.977,4.959,4.959],
                             'pe-16':[4.924,4.918,4.982,4.977,4.959,4.959],
                             'pe-32':[4.918,4.918,4.982,4.977,4.959,4.959],
                             'pe-64':[4.923,4.923,4.982,4.977,4.959,4.959]
                            })

dly_simd_diff = pd.DataFrame({'2': hls_dly_simd['pe-2']-rtl_dly_simd['pe-2'],
                            '4': hls_dly_simd['pe-4']-rtl_dly_simd['pe-4'],
                            '8': hls_dly_simd['pe-8']-rtl_dly_simd['pe-8'],
                            '16': hls_dly_simd['pe-16']-rtl_dly_simd['pe-16'],
                            '32': hls_dly_simd['pe-32']-rtl_dly_simd['pe-32'],
                            '64': hls_dly_simd['pe-64']-rtl_dly_simd['pe-64']})


dly_simd_diff = dly_simd_diff.set_index([pd.Index([2,4,8,16,32,64])])
# print(dly_simd_diff)
fig = plt.figure()
sns.set(font_scale=1.0)
ax=sns.heatmap(dly_simd_diff)
ax.invert_yaxis()
ax.set(xlabel='Processing elements (PEs)', ylabel='SIMDs')
plt.draw()
fig.savefig('paper_figs/pe_simd_heatmap_dly.eps', format='eps',bbox_inches='tight')
plt.show()

# %%
fontsize=12
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

### MLP

### XNOR
hls_mlp = pd.DataFrame({'lut':[],
                    'ff' :[],
                    'lat':[]})

rtl_mlp = pd.DataFrame({'lut':[678,2610,10113,30054],
                    'ff' :[992,2782,3139,6233]})

MLP = [8,16,32,64]
x = np.arange(len(MLP))  # the label locations
width = 0.25  # the width of the bars

rect_hls_lut = ax1.bar(x-width/2,hls_mlp['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax1.bar(x-width/2,hls_mlp['ff'],bottom=hls_mlp['lut'],width=width,label='HLS FF')
rect_hls_ff = ax1.bar(x+width/2,rtl_mlp['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax1.bar(x+width/2,rtl_mlp['ff'],bottom=rtl_mlp['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Resource count')
ax1.set_xlabel('MLP network size')
ax1.set_xticks(x)
ax1.set_xticklabels(MLP)
ax1.set_title("(a)")

## Plotting latency 
ax1a = ax1.twinx()
ax1a.plot(hls_mlp['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax1a.set_ylabel('Exec. cycles')

### Binary Weight
hls_mlp = pd.DataFrame({'lut':[],
                    'ff' :[],
                    'lat':[]})

rtl_mlp = pd.DataFrame({'lut':[],
                    'ff' :[]})

rect_hls_lut = ax2.bar(x-width/2,hls_mlp['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax2.bar(x-width/2,hls_mlp['ff'],bottom=hls_mlp['lut'],width=width,label='HLS FF')
rect_hls_ff = ax2.bar(x+width/2,rtl_mlp['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax2.bar(x+width/2,rtl_mlp['ff'],bottom=rtl_mlp['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Resource count')
ax2.set_xlabel('MLP network size')
ax2.set_xticks(x)
ax2.set_xticklabels(MLP)
ax2.set_title("(b)")

## Plotting latency 
ax2a = ax2.twinx()
ax2a.plot(hls_mlp['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax2a.set_ylabel('Exec. cycles')


### 4-bit
hls_mlp = pd.DataFrame({'lut':[619,2160,7929,27965],
                    'ff' :[844,3090,8661,28271],
                    'lat':[6,8,11,13]})

rtl_mlp = pd.DataFrame({'lut':[678,2610,10113,30054],
                    'ff' :[992,2782,3139,6233]})

rect_hls_lut = ax3.bar(x-width/2,hls_mlp['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax3.bar(x-width/2,hls_mlp['ff'],bottom=hls_mlp['lut'],width=width,label='HLS FF')
rect_hls_ff = ax3.bar(x+width/2,rtl_mlp['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax3.bar(x+width/2,rtl_mlp['ff'],bottom=rtl_mlp['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Resource count')
ax3.set_xlabel('MLP network size')
ax3.set_xticks(x)
ax3.set_xticklabels(MLP)
ax3.set_title("(c)")

## Plotting latency 
ax3a = ax3.twinx()
ax3a.plot(hls_mlp['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax3a.set_ylim(400000,15000000)
ax3a.set_ylabel('Exec. cycles')

fig.delaxes(ax4)
fig.tight_layout()

lines0,labels0=fig.axes[0].get_legend_handles_labels()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines0+lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.54,0.25), loc='lower left',ncol=2)

plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_mlp_final.svg', format='svg')
fig.savefig('paper_figs/res_util_mlp_final.eps', format='eps')
plt.show()

# %%
fontsize=12
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

### MLP

### XNOR
hls_mlp = pd.DataFrame({'dly':[]})

rtl_mlp = pd.DataFrame({'lut':[]})

MLP = [8,16,32,64]
x = np.arange(len(MLP))  # the label locations
width = 0.25  # the width of the bars

rect_hls_dly = ax1.bar(x-width/2,hls_mlp['dly'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_mlp['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Delay (ns)')
ax1.set_xlabel('MLP network size')
ax1.set_xticks(x)
ax1.set_xticklabels(MLP)
ax1.set_title("(a)")


### Binary Weight
hls_mlp = pd.DataFrame({'dly':[]})

rtl_mlp = pd.DataFrame({'lut':[]})

rect_hls_dly = ax1.bar(x-width/2,hls_mlp['dly'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_mlp['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Delay (ns)')
ax2.set_xlabel('MLP network size')
ax2.set_xticks(x)
ax2.set_xticklabels(MLP)
ax2.set_title("(b)")

### 4-bit
hls_mlp = pd.DataFrame({'dly':[5.019,4.557,4.405,5.58]})

rtl_mlp = pd.DataFrame({'lut':[1.267.1.443.2.831.4.953]})

rect_hls_dly = ax1.bar(x-width/2,hls_mlp['dly'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_mlp['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Delay (ns)')
ax3.set_xlabel('MLP network size')
ax3.set_xticks(x)
ax3.set_xticklabels(MLP)
ax3.set_title("(c)")

fig.delaxes(ax4)
fig.tight_layout()

lines0,labels0=fig.axes[0].get_legend_handles_labels()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines0+lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.54,0.25), loc='lower left',ncol=2)

plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_mlp_dly_final.svg', format='svg')
fig.savefig('paper_figs/res_util_mlp_dly_final.eps', format='eps')
plt.show()

# %%
fontsize=12
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(IFM_Ch))  # the label locations
width = 0.25  # the width of the bars

### IFM Dimension Plot with latency

### XNOR
hls_ifm = pd.DataFrame({'lut':[165,194,244,365,483,977],
                    'ff' :[241,275,341,472,737,1267],
                    'lat':[430596,861188,1722372,3444740,6889476,13778948]})

rtl_ifm = pd.DataFrame({'lut':[89,93,96,101,109,121],
                    'ff' :[133,135,138,140,148,150]})


rect_hls_lut = ax1.bar(x-width/2,hls_ifm['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax1.bar(x-width/2,hls_ifm['ff'],bottom=hls_ifm['lut'],width=width,label='HLS FF')
rect_hls_ff = ax1.bar(x+width/2,rtl_ifm['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax1.bar(x+width/2,rtl_ifm['ff'],bottom=rtl_ifm['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Resource count')
ax1.set_xlabel('IFM channels')
ax1.set_xticks(x)
ax1.set_xticklabels(IFM_Ch)
ax1.set_title("(a)")

## Plotting latency 
ax1a = ax1.twinx()
ax1a.plot(hls_ifm['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax1a.set_ylabel('Exec. cycles')

### Binary Weight
hls_ifm = pd.DataFrame({'lut':[245,298,403,623,1066,1829],
                    'ff' :[355,485,744,1257,2319,4391],
                    'lat':[430596,861188,1722372,3444740,6889476,13778948]})

rtl_ifm = pd.DataFrame({'lut':[139,143,146,157,176,138],
                    'ff' :[167,169,172,174,206,188]})

rect_hls_lut = ax2.bar(x-width/2,hls_ifm['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax2.bar(x-width/2,hls_ifm['ff'],bottom=hls_ifm['lut'],width=width,label='HLS FF')
rect_hls_ff = ax2.bar(x+width/2,rtl_ifm['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax2.bar(x+width/2,rtl_ifm['ff'],bottom=rtl_ifm['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Resource count')
ax2.set_xlabel('IFM channels')
ax2.set_xticks(x)
ax2.set_xticklabels(IFM_Ch)
ax2.set_title("(b)")

## Plotting latency 
ax2a = ax2.twinx()
ax2a.plot(hls_ifm['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax2a.set_ylabel('Exec. cycles')


### 4-bit
hls_ifm = pd.DataFrame({'lut':[298,343,437,578,1019,1963],
                    'ff' :[484,611,867,1383,2462,4579],
                    'lat':[430596,861188,1722372,3444740,6889476,13778948]})

rtl_ifm = pd.DataFrame({'lut':[185,185,191,199,218,184],
                    'ff' :[167,169,210,173,175,223]})

rect_hls_lut = ax3.bar(x-width/2,hls_ifm['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax3.bar(x-width/2,hls_ifm['ff'],bottom=hls_ifm['lut'],width=width,label='HLS FF')
rect_hls_ff = ax3.bar(x+width/2,rtl_ifm['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax3.bar(x+width/2,rtl_ifm['ff'],bottom=rtl_ifm['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Resource count')
ax3.set_xlabel('IFM channels')
ax3.set_xticks(x)
ax3.set_xticklabels(IFM_Ch)
ax3.set_title("(c)")

## Plotting latency 
ax3a = ax3.twinx()
ax3a.plot(hls_ifm['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax3a.set_ylim(400000,15000000)
ax3a.set_ylabel('Exec. cycles')

fig.delaxes(ax4)
fig.tight_layout()

lines0,labels0=fig.axes[0].get_legend_handles_labels()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines0+lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.54,0.25), loc='lower left',ncol=2)

plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_ifmch_final.svg', format='svg')
fig.savefig('paper_figs/res_util_ifmch_final.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=12
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

OFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(OFM_Ch))  # the label locations
width = 0.25  # the width of the bars

### IFM Dimension Plot with latency

### XNOR
hls_ofm = pd.DataFrame({'lut':[939,920,957,974,920,977],
                    'ff' :[1261,1257,1264,1260,1264,1267],
                    'lat':[430595,861187,1722371,3444739,6889475,13778947]})

rtl_ofm = pd.DataFrame({'lut':[94,105,114,115,117,121],
                    'ff' :[134,135,144,146,148,150]})


rect_hls_lut = ax1.bar(x-width/2,hls_ofm['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax1.bar(x-width/2,hls_ofm['ff'],bottom=hls_ofm['lut'],width=width,label='HLS FF')
rect_hls_ff = ax1.bar(x+width/2,rtl_ofm['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax1.bar(x+width/2,rtl_ofm['ff'],bottom=rtl_ofm['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Resource count')
ax1.set_xlabel('OFM channels')
ax1.set_xticks(x)
ax1.set_xticklabels(OFM_Ch)
ax1.set_title("(a)")

## Plotting latency 
ax1a = ax1.twinx()
ax1a.plot(hls_ofm['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax1a.set_ylabel('Exec. cycles')

### Binary Weight
hls_ofm = pd.DataFrame({'lut':[2050,1892,1811,1837,2020,1829],
                    'ff' :[4381,4398,4397,4409,4397,4391],
                    'lat':[430595,861187,1722371,3444739,6889475,13778947]})

rtl_ofm = pd.DataFrame({'lut':[114,125,132,134,136,138],
                    'ff' :[172,178,181,183,185,188]})

rect_hls_lut = ax2.bar(x-width/2,hls_ofm['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax2.bar(x-width/2,hls_ofm['ff'],bottom=hls_ofm['lut'],width=width,label='HLS FF')
rect_hls_ff = ax2.bar(x+width/2,rtl_ofm['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax2.bar(x+width/2,rtl_ofm['ff'],bottom=rtl_ofm['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Resource count')
ax2.set_xlabel('OFM channels')
ax2.set_xticks(x)
ax2.set_xticklabels(OFM_Ch)
ax2.set_title("(b)")

## Plotting latency 
ax2a = ax2.twinx()
ax2a.plot(hls_ofm['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax2a.set_ylabel('Exec. cycles')


### 4-bit
hls_ofm = pd.DataFrame({'lut':[1890,1972,1996,1941,1999,1963],
                    'ff' :[4517,4577,4580,4577,4585,4579],
                    'lat':[430596,861188,1722372,3444740,6889476,13778948]})

rtl_ofm = pd.DataFrame({'lut':[164,171,176,179,181,184],
                    'ff' :[209,214,216,218,220,223]})

rect_hls_lut = ax3.bar(x-width/2,hls_ofm['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax3.bar(x-width/2,hls_ofm['ff'],bottom=hls_ofm['lut'],width=width,label='HLS FF')
rect_hls_ff = ax3.bar(x+width/2,rtl_ofm['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax3.bar(x+width/2,rtl_ofm['ff'],bottom=rtl_ofm['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Resource count')
ax3.set_xlabel('OFM channels')
ax3.set_xticks(x)
ax3.set_xticklabels(OFM_Ch)
ax3.set_title("(c)")

## Plotting latency 
ax3a = ax3.twinx()
ax3a.plot(hls_ofm['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax3a.set_ylim(400000,15000000)
ax3a.set_ylabel('Exec. cycles')

fig.delaxes(ax4)
fig.tight_layout()

lines0,labels0=fig.axes[0].get_legend_handles_labels()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines0+lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.54,0.25), loc='lower left',ncol=2)

plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_ofmch_final.svg', format='svg')
fig.savefig('paper_figs/res_util_ofmch_final.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=8
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize

IFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(IFM_Ch))  # the label locations
width = 0.25  # the width of the bars

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

### XNOR
hls_ifm = pd.DataFrame({'dly': [2.427,2.48,2.636,2.57,2.583,2.598]})
rtl_ifm = pd.DataFrame({'dly': [3.577,3.6,3.594,3.592,3.585,3.58]});

print('IFM channels: XNOR')
print(np.min(hls_ifm['dly']),np.max(hls_ifm['dly']),np.mean(hls_ifm['dly']))
print(np.min(rtl_ifm['dly']),np.max(rtl_ifm['dly']),np.mean(rtl_ifm['dly']))
             
rect_hls_dly = ax1.bar(x-width/2,hls_ifm['dly'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_ifm['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Delay (ns)')
ax1.set_xlabel('IFM channels')
ax1.set_xticks(x)
ax1.set_xticklabels(IFM_Ch)
ax1.set_title("(a)")
ax1.grid()

### Binary Weights

hls_ifm = pd.DataFrame({'dly': [2.445,2.486,2.641,2.581,2.621,2.628]})
rtl_ifm = pd.DataFrame({'dly': [3.577,3.6,3.594,3.592,3.585,3.576]});
print('IFM channels: Bin. Wgt.')
print(np.min(hls_ifm['dly']),np.max(hls_ifm['dly']),np.mean(hls_ifm['dly']))
print(np.min(rtl_ifm['dly']),np.max(rtl_ifm['dly']),np.mean(rtl_ifm['dly']))

rect_hls_dly = ax2.bar(x-width/2,hls_ifm['dly'],width=width,label='HLS')
rect_rtl_dly = ax2.bar(x+width/2,rtl_ifm['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Delay (ns)')
ax2.set_xlabel('IFM channels')
ax2.set_xticks(x)
ax2.set_xticklabels(IFM_Ch)
ax2.set_title("(b)")
ax2.grid()

### Standard 4-bit
hls_ifm = pd.DataFrame({'dly': [7.357,7.441,7.416,7.416,7.441,7.384]})
rtl_ifm = pd.DataFrame({'dly': [3.473,3.473,3.594,3.457,3.459,3.391]});
print('IFM channels: Std.')
print(np.min(hls_ifm['dly']),np.max(hls_ifm['dly']),np.mean(hls_ifm['dly']))
print(np.min(rtl_ifm['dly']),np.max(rtl_ifm['dly']),np.mean(rtl_ifm['dly']))

rect_hls_dly = ax3.bar(x-width/2,hls_ifm['dly'],width=width,label='HLS')
rect_rtl_dly = ax3.bar(x+width/2,rtl_ifm['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Delay (ns)')
ax3.set_xlabel('IFM channels')
ax3.set_xticks(x)
ax3.set_xticklabels(IFM_Ch)
ax3.set_title("(c)")
ax3.grid()


fig.delaxes(ax4)

fig.tight_layout()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.75,0.25), loc='lower center',ncol=3)
plt.draw()
fig.savefig('paper_figs/res_final_ifmch_dly.svg', format='svg',bbox_inches='tight')
fig.savefig('paper_figs/res_final_ifmch_dly.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# IFM channels: XNOR
# 2.427 2.636 2.549
# 3.577 3.6 3.5879999999999996
# IFM channels: Bin. Wgt.
# 2.445 2.641 2.567
# 3.576 3.6 3.5873333333333335
# IFM channels: Std.
# 7.357 7.441 7.409166666666667
# 3.391 3.594 3.4745000000000004
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=8
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize

OFM_Ch = [2,4,8,16,32,64]
x = np.arange(len(OFM_Ch))  # the label locations
width = 0.25  # the width of the bars

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

### XNOR
hls_ofm = pd.DataFrame({'dly': [2.458,2.562,2.486,2.604,2.715,2.598]})
rtl_ofm = pd.DataFrame({'dly': [5-3.633,5-3.595,5-3.667,5-3.582,5-3.581,5-3.58]});
print('OFM channels: XNOR')
print(np.min(hls_ofm['dly']),np.max(hls_ofm['dly']),np.mean(hls_ofm['dly']))
print(np.min(rtl_ofm['dly']),np.max(rtl_ofm['dly']),np.mean(rtl_ofm['dly']))

rect_hls_dly = ax1.bar(x-width/2,hls_ofm['dly'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_ofm['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Delay (ns)')
ax1.set_xlabel('OFM channels')
ax1.set_xticks(x)
ax1.set_xticklabels(OFM_Ch)
ax1.set_title("(a)")
ax1.grid()

### Binary Weights

hls_ofm = pd.DataFrame({'dly': [2.476,2.497,2.552,2.556,2.651,2.628]})
rtl_ofm = pd.DataFrame({'dly': [5-3.579,5-3.579,5-3.579,5-3.579,5-3.578,5-3.576]});
print('OFM channels: Bin. Wgt.')
print(np.min(hls_ofm['dly']),np.max(hls_ofm['dly']),np.mean(hls_ofm['dly']))
print(np.min(rtl_ofm['dly']),np.max(rtl_ofm['dly']),np.mean(rtl_ofm['dly']))

rect_hls_dly = ax2.bar(x-width/2,hls_ofm['dly'],width=width,label='HLS')
rect_rtl_dly = ax2.bar(x+width/2,rtl_ofm['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Delay (ns)')
ax2.set_xlabel('OFM channels')
ax2.set_xticks(x)
ax2.set_xticklabels(OFM_Ch)
ax2.set_title("(b)")
ax2.grid()

### Standard 4-bit
hls_ofm = pd.DataFrame({'dly': [7.384,7.384,7.384,7.384,7.384,7.384]})
rtl_ofm = pd.DataFrame({'dly': [1.529,1.529,1.529,1.543,1.529,1.609]});
print('OFM channels: Std.')
print(np.min(hls_ofm['dly']),np.max(hls_ofm['dly']),np.mean(hls_ofm['dly']))
print(np.min(rtl_ofm['dly']),np.max(rtl_ofm['dly']),np.mean(rtl_ofm['dly']))

rect_hls_dly = ax3.bar(x-width/2,hls_ofm['dly'],width=width,label='HLS')
rect_rtl_dly = ax3.bar(x+width/2,rtl_ofm['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Delay (ns)')
ax3.set_xlabel('OFM channels')
ax3.set_xticks(x)
ax3.set_xticklabels(OFM_Ch)
ax3.set_title("(c)")
ax3.grid()


fig.delaxes(ax4)

fig.tight_layout()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.75,0.25), loc='lower center',ncol=3)
plt.draw()
fig.savefig('paper_figs/res_final_ofmch_dly.svg', format='svg',bbox_inches='tight')
fig.savefig('paper_figs/res_final_ofmch_dly.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# OFM channels: XNOR
# 2.458 2.715 2.5704999999999996
# 1.3330000000000002 1.42 1.3936666666666666
# OFM channels: Bin. Wgt.
# 2.476 2.651 2.56
# 1.4209999999999998 1.424 1.4216666666666666
# OFM channels: Std.
# 7.384 7.384 7.384
# 1.529 1.609 1.5446666666666669
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=12
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

PE = [1,2,4,8,16,32,64]
x = np.arange(len(PE))  # the label locations
width = 0.25  # the width of the bars

### IFM Dimension Plot with latency

### XNOR
hls_pe = pd.DataFrame({'lut':[596,718,990,1549,2734,5052,12571],
                    'ff' :[1406,1485,1647,1976,2630,4102,10661],
                    'lat':[25604,12804,6404,3204,1604,804,404]})

rtl_pe = pd.DataFrame({'lut':[290,443,748,1361,3776,6281,12404],
                    'ff' :[221,340,580,1063,3320,4801,9520]})


rect_hls_lut = ax1.bar(x-width/2,hls_pe['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax1.bar(x-width/2,hls_pe['ff'],bottom=hls_pe['lut'],width=width,label='HLS FF')
rect_hls_ff = ax1.bar(x+width/2,rtl_pe['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax1.bar(x+width/2,rtl_pe['ff'],bottom=rtl_pe['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Resource count')
ax1.set_xlabel('PEs')
ax1.set_xticks(x)
ax1.set_xticklabels(PE)
ax1.set_title("(a)")

## Plotting latency 
ax1a = ax1.twinx()
ax1a.plot(hls_pe['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax1a.set_ylabel('Exec. cycles')

### Binary Weight
hls_pe = pd.DataFrame({'lut':[2062,2583,3651,6025,10086,18612,36627],
                    'ff' :[5152,5314,5610,6196,7362,10248,19315],
                    'lat':[25604,12804,6404,3204,1604,804,404]})

rtl_pe = pd.DataFrame({'lut':[1272,2084,3295,7213,15219,28737,56932],
                    'ff' :[736,1271,2455,1048,3498,6696,10642]})

rect_hls_lut = ax2.bar(x-width/2,hls_pe['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax2.bar(x-width/2,hls_pe['ff'],bottom=hls_pe['lut'],width=width,label='HLS FF')
rect_hls_ff = ax2.bar(x+width/2,rtl_pe['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax2.bar(x+width/2,rtl_pe['ff'],bottom=rtl_pe['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Resource count')
ax2.set_xlabel('PEs')
ax2.set_xticks(x)
ax2.set_xticklabels(PE)
ax2.set_title("(b)")

## Plotting latency 
ax2a = ax2.twinx()
ax2a.plot(hls_pe['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax2a.set_ylabel('Exec. cycles')


### 4-bit
hls_pe = pd.DataFrame({'lut':[2997,4517,7540,13577,25792,50106,107320],
                    'ff' :[5675,6377,7629,9559,13970,23268,59444],
                    'lat':[25605,12805,6405,3205,1605,805,405]})

rtl_pe = pd.DataFrame({'lut':[2054,3656,7039,13237,31608,58306,112998],
                    'ff' :[1179,2057,3498,1101,1976,12077,23936]})

rect_hls_lut = ax3.bar(x-width/2,hls_pe['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax3.bar(x-width/2,hls_pe['ff'],bottom=hls_pe['lut'],width=width,label='HLS FF')
rect_hls_ff = ax3.bar(x+width/2,rtl_pe['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax3.bar(x+width/2,rtl_pe['ff'],bottom=rtl_pe['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Resource count')
ax3.set_xlabel('PEs')
ax3.set_xticks(x)
ax3.set_xticklabels(PE)
ax3.set_title("(c)")

## Plotting latency 
ax3a = ax3.twinx()
ax3a.plot(hls_pe['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax3a.set_ylim(400000,15000000)
ax3a.set_ylabel('Exec. cycles')

fig.delaxes(ax4)
fig.tight_layout()

lines0,labels0=fig.axes[0].get_legend_handles_labels()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines0+lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.54,0.25), loc='lower left',ncol=2)

plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_pe_final.svg', format='svg')
fig.savefig('paper_figs/res_util_pe_final.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=12
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

SIMD = [1,2,4,8,16,32,64]
x = np.arange(len(SIMD))  # the label locations
width = 0.25  # the width of the bars

### IFM Dimension Plot with latency

### XNOR
hls_simd = pd.DataFrame({'lut':[4648,3104,2893,3423,4714,7412,12566],
                    'ff' :[4234,4232,4229,4405,6241,8399,10666],
                    'lat':[25603,12803,6403,3203,1604,804,404]})

rtl_simd = pd.DataFrame({'lut':[1619,1649,1936,2197,3998,5571,12403],
                    'ff' :[3190,3252,3326,3396,4460,5757,9520]})


rect_hls_lut = ax1.bar(x-width/2,hls_simd['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax1.bar(x-width/2,hls_simd['ff'],bottom=hls_simd['lut'],width=width,label='HLS FF')
rect_hls_ff = ax1.bar(x+width/2,rtl_simd['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax1.bar(x+width/2,rtl_simd['ff'],bottom=rtl_simd['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Resource count')
ax1.set_xlabel('SIMDs/PE')
ax1.set_xticks(x)
ax1.set_xticklabels(SIMD)
ax1.set_title("(a)")

## Plotting latency 
ax1a = ax1.twinx()
ax1a.plot(hls_simd['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax1a.set_ylabel('Exec. cycles')

### Binary Weight
hls_simd = pd.DataFrame({'lut':[5311,5077,5873,8302,12959,22798,36813],
                    'ff' :[7382,7391,7723,8108,9842,12475,19333],
                    'lat':[25603,12803,6404,3204,1604,804,404]})

rtl_simd = pd.DataFrame({'lut':[1350,3122,3842,7916,14024,24784,51449],
                    'ff' :[3503,5372,4997,7467,7967,9155,11668]})

rect_hls_lut = ax2.bar(x-width/2,hls_simd['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax2.bar(x-width/2,hls_simd['ff'],bottom=hls_simd['lut'],width=width,label='HLS FF')
rect_hls_ff = ax2.bar(x+width/2,rtl_simd['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax2.bar(x+width/2,rtl_simd['ff'],bottom=rtl_simd['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Resource count')
ax2.set_xlabel('SIMDs/PE')
ax2.set_xticks(x)
ax2.set_xticklabels(SIMD)
ax2.set_title("(b)")

## Plotting latency 
ax2a = ax2.twinx()
ax2a.plot(hls_simd['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax1a.set_ylim(400000,15000000)
ax2a.set_ylabel('Exec. cycles')


### 4-bit
SIMD = [1,2,4,8,16,32,64]
x = np.arange(len(SIMD))  # the label locations

hls_simd = pd.DataFrame({'lut':[6274,5688,8090,14613,26682,50231,107315],
                    'ff' :[7949,8769,9182,10926,16919,19915,59430],
                    'lat':[25604,12803,6403,3203,1604,804,404]})
# 25603,
rtl_simd = pd.DataFrame({'lut':[2819,4320,8031,14350,27932,57430,112995],
                    'ff' :[4294,5512,9998,3998,5193,14319,23936]})

rect_hls_lut = ax3.bar(x-width/2,hls_simd['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax3.bar(x-width/2,hls_simd['ff'],bottom=hls_simd['lut'],width=width,label='HLS FF')
rect_hls_ff = ax3.bar(x+width/2,rtl_simd['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax3.bar(x+width/2,rtl_simd['ff'],bottom=rtl_simd['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Resource count')
ax3.set_xlabel('SIMDs/PE')
ax3.set_xticks(x)
ax3.set_xticklabels(SIMD)
ax3.set_title("(c)")

## Plotting latency 
ax3a = ax3.twinx()
ax3a.plot(hls_simd['lat'],color='black',marker='d',linewidth=2,
                markersize=6,markerfacecolor='magenta',label='Exec. cycles')
# ax3a.set_ylim(400000,15000000)
ax3a.set_ylabel('Exec. cycles')

fig.delaxes(ax4)
fig.tight_layout()

lines0,labels0=fig.axes[0].get_legend_handles_labels()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines0+lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.6,0.25), loc='lower left',ncol=2)

plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_simd_final.svg', format='svg')
fig.savefig('paper_figs/res_util_simd_final.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=8
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize

PE = [1,2,4,8,16,32,64]
x = np.arange(len(PE))  # the label locations
width = 0.25  # the width of the bars

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

### XNOR
hls_pe = pd.DataFrame({'dly': [2.536,2.515,2.509,2.747,2.595,2.492,2.47]})
rtl_pe = pd.DataFrame({'dly': [1.764,1.764,1.764,1.764,1.613,2.629,2.644]});
print('PE: XNOR')
print(np.min(hls_pe['dly']),np.max(hls_pe['dly']),np.mean(hls_pe['dly']))
print(np.min(rtl_pe['dly']),np.max(rtl_pe['dly']),np.mean(rtl_pe['dly']))

rect_hls_dly = ax1.bar(x-width/2,hls_pe['dly'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_pe['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Delay (ns)')
ax1.set_xlabel('PEs')
ax1.set_xticks(x)
ax1.set_xticklabels(PE)
ax1.set_title("(a)")
ax1.grid()

### Binary Weights

hls_pe = pd.DataFrame({'dly': [3.842,3.842,3.842,3.954,3.952,3.98,4.009]})
rtl_pe = pd.DataFrame({'dly': [1.833,1.833,1.912,3.327,3.019,3.034,3.231]});
print('PE: Bin. Wgt.')
print(np.min(hls_pe['dly']),np.max(hls_pe['dly']),np.mean(hls_pe['dly']))
print(np.min(rtl_pe['dly']),np.max(rtl_pe['dly']),np.mean(rtl_pe['dly']))

rect_hls_dly = ax2.bar(x-width/2,hls_pe['dly'],width=width,label='HLS')
rect_rtl_dly = ax2.bar(x+width/2,rtl_pe['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Delay (ns)')
ax2.set_xlabel('PEs')
ax2.set_xticks(x)
ax2.set_xticklabels(PE)
ax2.set_title("(b)")
ax2.grid()

### Standard 4-bit
hls_pe = pd.DataFrame({'dly': [8.087,8.23,8.23,8.977,8.908,8.911,8.977]})
rtl_pe = pd.DataFrame({'dly': [2.002,2.002,2,3.282,4.884,3.045,3.07]});
print('PE: Std.')
print(np.min(hls_pe['dly']),np.max(hls_pe['dly']),np.mean(hls_pe['dly']))
print(np.min(rtl_pe['dly']),np.max(rtl_pe['dly']),np.mean(rtl_pe['dly']))

rect_hls_dly = ax3.bar(x-width/2,hls_pe['dly'],width=width,label='HLS')
rect_rtl_dly = ax3.bar(x+width/2,rtl_pe['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Delay (ns)')
ax3.set_xlabel('PEs')
ax3.set_xticks(x)
ax3.set_xticklabels(PE)
ax3.set_title("(c)")
ax3.grid()


fig.delaxes(ax4)

fig.tight_layout()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.75,0.25), loc='lower center',ncol=3)
plt.draw()
fig.savefig('paper_figs/res_final_pe_dly.svg', format='svg',bbox_inches='tight')
fig.savefig('paper_figs/res_final_pe_dly.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# PE: XNOR
# 2.47 2.747 2.552
# 1.613 2.644 1.9917142857142858
# PE: Bin. Wgt.
# 3.842 4.009 3.9172857142857147
# 1.833 3.327 2.5984285714285713
# PE: Std.
# 8.087 8.977 8.617142857142857
# 2.0 4.884 2.8978571428571427
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=8
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize

SIMD = [1,2,4,8,16,32,64]
x = np.arange(len(SIMD))  # the label locations
width = 0.25  # the width of the bars

fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

### XNOR
hls_simd = pd.DataFrame({'dly': [2.704,2.936,2.677,2.658,2.911,2.538,2.244]})
rtl_simd = pd.DataFrame({'dly': [1.829,1.823,1.813,1.66,1.437,1.806,2.644]});
print('PE: XNOR')
print(np.min(hls_simd['dly']),np.max(hls_simd['dly']),np.mean(hls_simd['dly']))
print(np.min(rtl_simd['dly']),np.max(rtl_simd['dly']),np.mean(rtl_simd['dly']))
rect_hls_dly = ax1.bar(x-width/2,hls_simd['dly'],width=width,label='HLS')
rect_rtl_dly = ax1.bar(x+width/2,rtl_simd['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Delay (ns)')
ax1.set_xlabel('SIMDs')
ax1.set_xticks(x)
ax1.set_xticklabels(PE)
ax1.set_title("(a)")
ax1.grid()

### Binary Weights

hls_simd = pd.DataFrame({'dly': [2.698,3.146,2.747,2.829,3.87,4.531,3.891]})
rtl_simd = pd.DataFrame({'dly': [1.829,1.823,1.879,1.684,2.949,2.955,3.231]});
print('PE: Bin. Wgt.')
print(np.min(hls_simd['dly']),np.max(hls_simd['dly']),np.mean(hls_simd['dly']))
print(np.min(rtl_simd['dly']),np.max(rtl_simd['dly']),np.mean(rtl_simd['dly']))
rect_hls_dly = ax2.bar(x-width/2,hls_simd['dly'],width=width,label='HLS')
rect_rtl_dly = ax2.bar(x+width/2,rtl_simd['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Delay (ns)')
ax2.set_xlabel('SIMDs')
ax2.set_xticks(x)
ax2.set_xticklabels(SIMD)
ax2.set_title("(b)")
ax2.grid()

### Standard 4-bit
x = np.arange(len(SIMD))  # the label locations

hls_simd = pd.DataFrame({'dly': [7.89,7.586,9.374,7.063,7.779,7.591,8.977]})
rtl_simd = pd.DataFrame({'dly': [1.829,1.879,1.814,2.867,2.641,3.072,3.07]});
print('PE: Std.')
print(np.min(hls_simd['dly']),np.max(hls_simd['dly']),np.mean(hls_simd['dly']))
print(np.min(rtl_simd['dly']),np.max(rtl_simd['dly']),np.mean(rtl_simd['dly']))
rect_hls_dly = ax3.bar(x-width/2,hls_simd['dly'],width=width,label='HLS')
rect_rtl_dly = ax3.bar(x+width/2,rtl_simd['dly'],width=width,label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Delay (ns)')
ax3.set_xlabel('SIMDs')
ax3.set_xticks(x)
ax3.set_xticklabels(SIMD)
ax3.set_title("(c)")
ax3.grid()


fig.delaxes(ax4)

fig.tight_layout()
lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.75,0.25), loc='lower center',ncol=3)
plt.draw()
fig.savefig('paper_figs/res_final_simd_dly.svg', format='svg',bbox_inches='tight')
fig.savefig('paper_figs/res_final_simd_dly.eps', format='eps',bbox_inches='tight')
plt.show()
# Out:
# PE: XNOR
# 2.244 2.936 2.666857142857143
# 1.437 2.644 1.8588571428571428
# PE: Bin. Wgt.
# 2.698 4.531 3.387428571428571
# 1.684 3.231 2.335714285714286
# PE: Std.
# 7.063 9.374 8.037142857142857
# 1.814 3.072 2.4531428571428573
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=12
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

OWL = [11,12,13,14,15,16]
x = np.arange(len(OWL))  # the label locations
width = 0.25  # the width of the bars

### Word length

### XNOR
hls_wl = pd.DataFrame({'lut':[3252,2951,2956,3156,2683,2716],
                    'ff' :[2327,2423,2520,2616,2709,2804]})

rtl_wl = pd.DataFrame({'lut':[2087,2142,2199,2239,2295,2336],
                    'ff' :[1920,2018,2114,2211,2307,2404]})


rect_hls_lut = ax1.bar(x-width/2,hls_wl['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax1.bar(x-width/2,hls_wl['ff'],bottom=hls_wl['lut'],width=width,label='HLS FF')
rect_hls_ff = ax1.bar(x+width/2,rtl_wl['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax1.bar(x+width/2,rtl_wl['ff'],bottom=rtl_wl['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Resource count')
ax1.set_xlabel('Output word length')
ax1.set_xticks(x)
ax1.set_xticklabels(OWL)
ax1.set_title("(a)")
ax1.grid()
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.set_facecolor([235/255,235/255,243/255,255/255])


# ### Binary Weight
hls_wl = pd.DataFrame({'lut':[10420,10649,10998,11465,11780,11761],
                    'ff' :[7223,7304,7382,7383,7464,7564]})

rtl_wl = pd.DataFrame({'lut':[10050,10605,11382,11956,12523,13113],
                    'ff' :[2630,3602,4377,4165,4433,4784]})

rect_hls_lut = ax2.bar(x-width/2,hls_wl['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax2.bar(x-width/2,hls_wl['ff'],bottom=hls_wl['lut'],width=width,label='HLS FF')
rect_hls_ff = ax2.bar(x+width/2,rtl_wl['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax2.bar(x+width/2,rtl_wl['ff'],bottom=rtl_wl['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Resource count')
ax2.set_xlabel('Output word length')
ax2.set_xticks(x)
ax2.set_xticklabels(OWL)
ax2.set_title("(b)")
ax2.grid()
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.set_facecolor([235/255,235/255,243/255,255/255])


### 4-bit
hls_wl = pd.DataFrame({'lut':[26199,25637,25483,25652,25575,25627],
                    'ff' :[12749,13283,11862,18210,12120,12244]})

rtl_wl = pd.DataFrame({'lut':[32428,30797,30879,30984,30935,31072],
                    'ff' :[7066,7504,7581,7705,7322,7899]})

rect_hls_lut = ax3.bar(x-width/2,hls_wl['lut'],width=width,label='HLS LUT')
rect_rtl_lut = ax3.bar(x-width/2,hls_wl['ff'],bottom=hls_wl['lut'],width=width,label='HLS FF')
rect_hls_ff = ax3.bar(x+width/2,rtl_wl['lut'],width=width,label='RTL LUT')
rect_rtl_ff = ax3.bar(x+width/2,rtl_wl['ff'],bottom=rtl_wl['lut'],width=width,label='RTL FF')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax3.set_ylabel('Resource count')
ax3.set_xlabel('Output word length')
ax3.set_xticks(x)
ax3.set_xticklabels(OWL)
ax3.set_title("(c)")
ax1.grid()
ax3.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.set_facecolor([235/255,235/255,243/255,255/255])


fig.delaxes(ax4)
fig.tight_layout()

lines0,labels0=fig.axes[0].get_legend_handles_labels()
# lines1,labels1=fig.axes[-1].get_legend_handles_labels()
lines=lines0#+lines1
labels=[l.get_label() for l in lines]
plt.figlegend(lines,labels,bbox_to_anchor=(0.54,0.25), loc='lower left',ncol=2)
plt.grid()
plt.draw()
fig.savefig('paper_figs/res_util_owl_final.svg', format='svg')
fig.savefig('paper_figs/res_util_owl_final.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fontsize=16
plt.rcParams["font.family"] = "serif"
plt.rcParams["font.size"] = fontsize
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,sharex=True,figsize=(10,6))

PE = [1,2,4,8,16,32,64]
hls_exec = [1026.536,1045.3,1088.477,1095.105,1200.601,1492.561,2632.23]
rtl_exec = [98.129,104.442,103.047,105.019,124.66,150.042,202.88]

x = np.arange(len(PE))  # the label locations
width = 0.35  # the width of the bars

rects1 = ax1.bar(x - width/2, hls_exec, width, label='HLS')
rects2 = ax1.bar(x + width/2, rtl_exec, width, label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax1.set_ylabel('Synthesis time (sec.)')
ax1.set_xlabel('Processing elements (PEs)')
ax1.set_xticks(x)
ax1.set_xticklabels(PE)
ax1.set_title('(a)')
ax1.legend()

SIMD = [1,2,4,8,16,32,64]
hls_exec = [1762.452,1224.871,1109.87,1141.112,1224.022,1530.787,2615.679]
rtl_exec = [131.955,129.995,109.842,137.167,169.923,261.734,226.711]

x = np.arange(len(SIMD))  # the label locations
width = 0.35  # the width of the bars

rects1 = ax2.bar(x - width/2, hls_exec, width, label='HLS')
rects2 = ax2.bar(x + width/2, rtl_exec, width, label='RTL')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax2.set_ylabel('Synthesis time (sec.)')
ax2.set_xlabel('SIMD')
ax2.set_xticks(x)
ax2.set_xticklabels(SIMD)
ax2.set_title('(b)')
ax2.legend()


fig.delaxes(ax3)
fig.delaxes(ax4)

fig.tight_layout()
plt.draw()
fig.savefig('paper_figs/exec_time_pe_simd.svg', format='svg', bbox_inches='tight')
fig.savefig('paper_figs/exec_time_pe_simd.eps', format='eps', bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
with open("report.txt") as f:
    for l in f:
        l = l.rstrip()
        if(('Setup' in l) and ('Worst Slack' in l)):
            i = l.split(',')[1].split(' ')[-1]
            j = len(i)
            k = float(i[:j-2])
            print(k)
#             j = i[1]
#             k = j.split(' ')
#             m = k[-1]
#             ml = len(m)
#             n = m[:ml-2]
#             print(n)
# Out:
# 3.264

# %%
a = ['asad',0]
b = ['alam',1]
for x in zip(a,b):
    if((type(x[0])==str) and (type(x[1])==str)):
        print("True")
    else:    
        print("False")
# Out:
# True
# False

# %%
type(x[0])
# Out:
# int

# %%
hls = [8.087,8.977,8.617,7.063,9.374,8.037]
rtl = [2.0, 4.884, 2.898, 1.814, 3.072, 2.453]

# %%
for h,r in zip(hls,rtl):
    print((h-r)/h*100)
# Out:
# 75.26895016693459
# 45.59429653559095
# 66.36880584890334
# 74.31686252300722
# 67.22850437379986
# 69.47866119198707

# %%
hls = [7.357,  7.441,   7.409,7.384,  7.384,   7.384]
rtl = [1.406,  1.609  , 1.526, 1.529,  1.609,   1.545]
for h,r in zip(hls,rtl):
    print((h-r)/h*100)
# Out:
# 80.88894929998641
# 78.37656229001479
# 79.40342826292347
# 79.29306608884073
# 78.20964247020585
# 79.07638136511376

# %%
hls = [ 2.427 , 2.636,   2.549, 2.445,  2.641,   2.567, 2.458  ,2.715  , 2.570, 2.476  ,2.651   ,2.560]
rtl = [1.4   ,1.423   ,1.412,1.4,   1.424,   1.413,1.333   ,1.42   ,1.394,1.421  ,1.424  , 1.422]
for h,r in zip(hls,rtl):
    print((h-r)/h*100)
# Out:
# 42.315615986815004
# 46.01669195751138
# 44.60572773636721
# 42.740286298568506
# 46.08102991291178
# 44.955200623295674
# 45.76891781936535
# 47.697974217311234
# 45.75875486381323
# 42.60904684975767
# 46.28442097321766
# 44.45312500000001
